# %%
training_name = 'training-toy-version3a'

testmode = False
#testmode = True

run_training = True
#run_training = False

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.colors import LogNorm
from matplotlib import rc
from numpy import inf
import os
import sys
from IPython import display


#-- this selects the GPU to use (0 or 1)
os.environ['CUDA_VISIBLE_DEVICES']="1"

from os import listdir

from pickle import dump
from pickle import load

import uproot3

import matplotlib as mpl

from datetime import datetime
import subprocess

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.losses import Loss, BinaryCrossentropy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import keras

from tensorflow.python.client import device_lib

from pickle import dump


#has_gpu = False

has_gpu = True



from tensorflow.keras.callbacks import EarlyStopping
earlystopping = EarlyStopping(patience=20,
               verbose=True,
               restore_best_weights=True)

import os

print(tf.config.list_physical_devices())

if has_gpu :
    #os.environ['CUDA_VISIBLE_DEVICES']="0"
    physical_devices = tf.config.list_physical_devices('GPU') 
    tf.config.experimental.set_memory_growth(physical_devices[0], True)


    print("\n\n printing physical devbices from tf.config.list_physical_devices\n\n")
    print(physical_devices)

    devices = device_lib.list_local_devices()

    print("\n\n printing devices from device_lib.list_local_devices\n\n")
    print(devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
#
#  printing physical devbices from tf.config.list_physical_devices
#
#
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
#
#  printing devices from device_lib.list_local_devices
#
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 576556716480328103
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 23344578560
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 8204343918594329379
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# 2023-12-18 09:39:29.924878: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:29.952294: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:29.952596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:29.957269: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:29.957516: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:29.957743: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:30.495549: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:30.495831: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:30.496069: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:30.496275: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 22263 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6

# %% [markdown]
# ## Generate toy data

# %%
#ntoy = 100000

#ntoy = 400000

ntoy = 1000000

#mu_min = -1.
#mu_max = 1.


mu_min = -3.
mu_max = 3.






#z0_sig = 1.0
#z1_sig = 0.2

#x0_sig = 0.2
#x1_sig = 1.0





z0_sig = 0.5
z1_sig = 0.1

x0_sig = 0.1
x1_sig = 0.5






#z0_sig = 0.3
#z1_sig = 0.1

#x0_sig = 0.1
#x1_sig = 0.3




mu = np.random.uniform(mu_min, mu_max, ntoy)


z0 = np.random.normal(mu,z0_sig)
z1 = np.random.normal(mu,z1_sig)


x0 = np.random.normal(z0, x0_sig)
x1 = np.random.normal(z1, x1_sig)

# %%
diff_z0 = mu - z0

# %%
fig,ax = plt.subplots(3,5,figsize=(20,12))

ax[0][0].hist(mu, bins=80)
ax[0][1].hist(z0, bins=80)
ax[0][2].hist(z1, bins=80)
ax[0][3].hist(x0, bins=80)
ax[0][4].hist(x1, bins=80)


ax[1][1].hist2d(mu,z0, bins=[80,80])
ax[1][2].hist2d(mu,z1, bins=[80,80])
ax[1][3].hist2d(mu,x0, bins=[80,80])
ax[1][4].hist2d(mu,x1, bins=[80,80])

ax[2][3].hist2d(z0,x0, bins=[80,80])
ax[2][4].hist2d(z1,x1, bins=[80,80])


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
if run_training :
    
    try:
        os.mkdir( '%s-training-output' % training_name )
    except:
        print('\n  Dir %s-training-output already exists\n\n' % training_name )
        #print('\n\n HALTING EXECUTION \n\n')
        #sys.exit()


learning_rate_setval = 5e-5
batch_size_setval = 512
max_epochs = 5000
amsgrad_setval = False
patience_setval = 40
hp_lambda = 1.0

if testmode :

#-- settings for quick syntax checking runthrough
    max_events =   600000
    learning_rate_setval = 1e-3
    batch_size_setval = 4096
    max_epochs = 200








output_dir = '%s-training-output' % training_name
# Out:
#   Dir training-toy-version3a-training-output already exists

# %%
X = np.c_[
    z0,
    z1,
    x0,
    x1,
]

Y = np.c_[
    mu
]

# %%
scaler_file = "%s/input-scaler.pkl" % output_dir

if run_training :
    print("Creating new scaler.")
    scalerX = StandardScaler()
    scalerX.fit(X)
else :
    print("Reading scaler from file: %s" % scaler_file )
    scalerX = load( open(scaler_file, 'rb') )
    
Xs = scalerX.transform(X)


if run_training :
    print("Saving scaler to %s" % scaler_file)
    dump( scalerX, open(scaler_file, 'wb'))
# Out:
# Creating new scaler.
# Saving scaler to training-toy-version3a-training-output/input-scaler.pkl

# %%
X_train, X_test, Y_train, Y_test = train_test_split( Xs, Y, test_size=0.5 )
#X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.5 )

# %%
fig,ax = plt.subplots(2,4,figsize=(18,8))


ax[0][0].hist( X[:,0], bins=80)
ax[0][1].hist( X[:,1], bins=80)
ax[0][2].hist( X[:,2], bins=80)
ax[0][3].hist( X[:,3], bins=80)

ax[1][0].hist( Xs[:,0], bins=80)
ax[1][1].hist( Xs[:,1], bins=80)
ax[1][2].hist( Xs[:,2], bins=80)
ax[1][3].hist( Xs[:,3], bins=80)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X_train
# Out:
# array([[ 0.71702318,  0.72352934,  0.64974631,  0.51574714],
#        [ 1.28429172,  1.01609394,  1.31583282,  1.05085845],
#        [ 1.56684518,  1.14724848,  1.53880338,  0.90331329],
#        ...,
#        [-0.65580487, -0.83963416, -0.63028624,  0.06664093],
#        [ 1.10223158,  1.41806498,  1.09181091,  1.45078503],
#        [ 0.48781234,  0.40445842,  0.47015596,  0.1192934 ]])

# %%
Y_train
# Out:
# array([[ 1.37906865],
#        [ 1.81478488],
#        [ 2.0861032 ],
#        ...,
#        [-1.35463577],
#        [ 2.46916578],
#        [ 0.65776369]])

# %%
np.shape(X_train)
# Out:
# (500000, 4)

# %%
np.shape(Y_train)
# Out:
# (500000, 1)

# %%
def train_model( mse_sf ) :
    
    huber = tf.keras.losses.Huber(delta=10)
    
    def custom_loss(y_true, y_pred):
        particle_level = y_pred[:,0]
        detector_level = y_pred[:,1]
        loss =  huber(y_true, particle_level) + mse_sf * tf.reduce_mean(tf.square(particle_level - detector_level)) 
        #loss =  huber(y_true, detector_level) + mse_sf * tf.reduce_mean(tf.square(particle_level - detector_level)) 
        return loss    

    n = 2  # Number of features in input.

    inputs = Input(shape=(2*n,))

    classifier_nn = Sequential()
    classifier_nn.add( Dense( 50, activation="relu", input_dim=n) )
    classifier_nn.add( Dense( 50, activation="relu"))
    classifier_nn.add( Dense( 1, activation="linear"))

    particle_inputs_model2 = classifier_nn( inputs[:,0:n] )
    detector_inputs_model2 = classifier_nn( inputs[:,n:] )

    output2 = tf.stack( [particle_inputs_model2, detector_inputs_model2], axis=1)


    mymodel2 = Model( inputs=[inputs], outputs=[output2])


    opt_adam = tf.keras.optimizers.Adam(learning_rate=learning_rate_setval, amsgrad=False )

    mymodel2.compile( loss=custom_loss, optimizer=opt_adam, metrics=['accuracy'] )


    
    
    training_hist2 = mymodel2.fit( X_train, Y_train, validation_data=(X_test, Y_test), 
            epochs=50, 
            batch_size=batch_size_setval,
           verbose=1)

    plt.plot( training_hist2.history['loss'] )
    plt.plot( training_hist2.history['val_loss'] )
    
    mymodel2.summary()
    
    return mymodel2

# %%
num_sf = 6

sf_val = [0., 0.2, 0.6, 1., 2., 4. ]

sf_ind = 0

# %%
# %%time

model_sf_array = []

if run_training :
    for sfi in range(0, num_sf) :
        print("\n\n =============== Training with SF = ", sf_val[sfi], "\n\n" )
        model = train_model( sf_val[sfi])
        model_sf_array.append(model)
        tf.keras.models.save_model( model, "%s/model-sf-%.1f" % (output_dir, sf_val[sfi] ) )
else :
    for sfi in range(0, num_sf) :
        print("\n ======= Loading model for SF = ", sf_val[sfi],"\n\n")
        model = tf.keras.models.load_model( "%s/model-sf-%.1f" % (output_dir, sf_val[sfi] ), compile=False )
        model_sf_array.append(model)
# Out:
#  =============== Training with SF =  0.0
#
#
# Epoch 1/50
# 2023-12-18 09:39:33.276359: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:33.276666: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:33.276896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:33.277168: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:33.277399: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-12-18 09:39:33.277591: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22263 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6
# 2023-12-18 09:39:35.058682: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-12-18 09:39:35.062186: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f75f800da30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-18 09:39:35.062217: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-12-18 09:39:35.070999: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-18 09:39:35.192445: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 977/977 [==============================] - 6s 4ms/step - loss: 0.4355 - accuracy: 0.0000e+00 - val_loss: 0.0161 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0052 - accuracy: 0.0000e+00 - val_loss: 0.0050 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0049 - accuracy: 0.0000e+00 - val_loss: 0.0049 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 4)]          0           []
#
#  tf.__operators__.getitem (Slic  (None, 2)           0           ['input_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 2)           0           ['input_1[0][0]']
#  icingOpLambda)
#
#  sequential (Sequential)        (None, 1)            2751        ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]']
#
#  tf.stack (TFOpLambda)          (None, 2, 1)         0           ['sequential[0][0]',
#                                                                   'sequential[1][0]']
#
# ==================================================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: training-toy-version3a-training-output/model-sf-0.0/assets
#
#
#  =============== Training with SF =  0.2
#
#
# Epoch 1/50
# 977/977 [==============================] - 5s 4ms/step - loss: 0.6098 - accuracy: 0.0000e+00 - val_loss: 0.0659 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0443 - accuracy: 0.0000e+00 - val_loss: 0.0387 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0371 - accuracy: 0.0000e+00 - val_loss: 0.0358 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0352 - accuracy: 0.0000e+00 - val_loss: 0.0346 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0344 - accuracy: 0.0000e+00 - val_loss: 0.0341 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0340 - accuracy: 0.0000e+00 - val_loss: 0.0338 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0337 - accuracy: 0.0000e+00 - val_loss: 0.0335 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0334 - accuracy: 0.0000e+00 - val_loss: 0.0332 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0332 - accuracy: 0.0000e+00 - val_loss: 0.0330 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0329 - accuracy: 0.0000e+00 - val_loss: 0.0327 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0327 - accuracy: 0.0000e+00 - val_loss: 0.0325 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0325 - accuracy: 0.0000e+00 - val_loss: 0.0324 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0324 - accuracy: 0.0000e+00 - val_loss: 0.0322 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0322 - accuracy: 0.0000e+00 - val_loss: 0.0321 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0321 - accuracy: 0.0000e+00 - val_loss: 0.0320 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0320 - accuracy: 0.0000e+00 - val_loss: 0.0319 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0320 - accuracy: 0.0000e+00 - val_loss: 0.0318 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0319 - accuracy: 0.0000e+00 - val_loss: 0.0318 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0318 - accuracy: 0.0000e+00 - val_loss: 0.0317 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0318 - accuracy: 0.0000e+00 - val_loss: 0.0316 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0317 - accuracy: 0.0000e+00 - val_loss: 0.0316 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0317 - accuracy: 0.0000e+00 - val_loss: 0.0316 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0316 - accuracy: 0.0000e+00 - val_loss: 0.0315 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0316 - accuracy: 0.0000e+00 - val_loss: 0.0315 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0316 - accuracy: 0.0000e+00 - val_loss: 0.0315 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.0000e+00 - val_loss: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.0000e+00 - val_loss: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.0000e+00 - val_loss: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.0000e+00 - val_loss: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0315 - accuracy: 0.0000e+00 - val_loss: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0313 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0313 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0313 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0313 - accuracy: 0.0000e+00 - val_loss: 0.0313 - val_accuracy: 0.0000e+00
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 4)]          0           []
#
#  tf.__operators__.getitem_2 (Sl  (None, 2)           0           ['input_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None, 2)           0           ['input_2[0][0]']
#  icingOpLambda)
#
#  sequential_1 (Sequential)      (None, 1)            2751        ['tf.__operators__.getitem_2[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  tf.stack_1 (TFOpLambda)        (None, 2, 1)         0           ['sequential_1[0][0]',
#                                                                   'sequential_1[1][0]']
#
# ==================================================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: training-toy-version3a-training-output/model-sf-0.2/assets
#
#
#  =============== Training with SF =  0.6
#
#
# Epoch 1/50
# 977/977 [==============================] - 5s 4ms/step - loss: 0.6081 - accuracy: 0.0000e+00 - val_loss: 0.1032 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0693 - accuracy: 0.0000e+00 - val_loss: 0.0641 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0637 - accuracy: 0.0000e+00 - val_loss: 0.0633 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0631 - accuracy: 0.0000e+00 - val_loss: 0.0627 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0626 - accuracy: 0.0000e+00 - val_loss: 0.0623 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0621 - accuracy: 0.0000e+00 - val_loss: 0.0617 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0615 - accuracy: 0.0000e+00 - val_loss: 0.0611 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0608 - accuracy: 0.0000e+00 - val_loss: 0.0604 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0601 - accuracy: 0.0000e+00 - val_loss: 0.0598 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0596 - accuracy: 0.0000e+00 - val_loss: 0.0593 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0592 - accuracy: 0.0000e+00 - val_loss: 0.0590 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0589 - accuracy: 0.0000e+00 - val_loss: 0.0587 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0587 - accuracy: 0.0000e+00 - val_loss: 0.0585 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0585 - accuracy: 0.0000e+00 - val_loss: 0.0583 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0583 - accuracy: 0.0000e+00 - val_loss: 0.0582 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0582 - accuracy: 0.0000e+00 - val_loss: 0.0581 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0581 - accuracy: 0.0000e+00 - val_loss: 0.0580 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0580 - accuracy: 0.0000e+00 - val_loss: 0.0579 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0580 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0579 - accuracy: 0.0000e+00 - val_loss: 0.0578 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0579 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0578 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0578 - accuracy: 0.0000e+00 - val_loss: 0.0577 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0578 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0577 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0576 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0576 - accuracy: 0.0000e+00 - val_loss: 0.0575 - val_accuracy: 0.0000e+00
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 4)]          0           []
#
#  tf.__operators__.getitem_4 (Sl  (None, 2)           0           ['input_3[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  (None, 2)           0           ['input_3[0][0]']
#  icingOpLambda)
#
#  sequential_2 (Sequential)      (None, 1)            2751        ['tf.__operators__.getitem_4[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_5[0][0
#                                                                  ]']
#
#  tf.stack_2 (TFOpLambda)        (None, 2, 1)         0           ['sequential_2[0][0]',
#                                                                   'sequential_2[1][0]']
#
# ==================================================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: training-toy-version3a-training-output/model-sf-0.6/assets
#
#
#  =============== Training with SF =  1.0
#
#
# Epoch 1/50
# 977/977 [==============================] - 5s 4ms/step - loss: 0.5853 - accuracy: 0.0000e+00 - val_loss: 0.0899 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0828 - accuracy: 0.0000e+00 - val_loss: 0.0803 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0794 - accuracy: 0.0000e+00 - val_loss: 0.0786 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0781 - accuracy: 0.0000e+00 - val_loss: 0.0775 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0771 - accuracy: 0.0000e+00 - val_loss: 0.0766 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0762 - accuracy: 0.0000e+00 - val_loss: 0.0758 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0755 - accuracy: 0.0000e+00 - val_loss: 0.0750 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0748 - accuracy: 0.0000e+00 - val_loss: 0.0744 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0742 - accuracy: 0.0000e+00 - val_loss: 0.0739 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0738 - accuracy: 0.0000e+00 - val_loss: 0.0735 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0735 - accuracy: 0.0000e+00 - val_loss: 0.0733 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0732 - accuracy: 0.0000e+00 - val_loss: 0.0730 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0730 - accuracy: 0.0000e+00 - val_loss: 0.0728 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0729 - accuracy: 0.0000e+00 - val_loss: 0.0726 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0727 - accuracy: 0.0000e+00 - val_loss: 0.0725 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 977/977 [==============================] - 3s 4ms/step - loss: 0.0726 - accuracy: 0.0000e+00 - val_loss: 0.0724 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0725 - accuracy: 0.0000e+00 - val_loss: 0.0724 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0725 - accuracy: 0.0000e+00 - val_loss: 0.0723 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0722 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0724 - accuracy: 0.0000e+00 - val_loss: 0.0722 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0722 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0723 - accuracy: 0.0000e+00 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0721 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0722 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0720 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0721 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0720 - accuracy: 0.0000e+00 - val_loss: 0.0719 - val_accuracy: 0.0000e+00
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 4)]          0           []
#
#  tf.__operators__.getitem_6 (Sl  (None, 2)           0           ['input_4[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_7 (Sl  (None, 2)           0           ['input_4[0][0]']
#  icingOpLambda)
#
#  sequential_3 (Sequential)      (None, 1)            2751        ['tf.__operators__.getitem_6[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  tf.stack_3 (TFOpLambda)        (None, 2, 1)         0           ['sequential_3[0][0]',
#                                                                   'sequential_3[1][0]']
#
# ==================================================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: training-toy-version3a-training-output/model-sf-1.0/assets
#
#
#  =============== Training with SF =  2.0
#
#
# Epoch 1/50
# 977/977 [==============================] - 5s 4ms/step - loss: 0.4938 - accuracy: 0.0000e+00 - val_loss: 0.1205 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1068 - accuracy: 0.0000e+00 - val_loss: 0.1021 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1008 - accuracy: 0.0000e+00 - val_loss: 0.0998 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0991 - accuracy: 0.0000e+00 - val_loss: 0.0985 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0979 - accuracy: 0.0000e+00 - val_loss: 0.0973 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0969 - accuracy: 0.0000e+00 - val_loss: 0.0964 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0962 - accuracy: 0.0000e+00 - val_loss: 0.0958 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0956 - accuracy: 0.0000e+00 - val_loss: 0.0952 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0951 - accuracy: 0.0000e+00 - val_loss: 0.0947 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0946 - accuracy: 0.0000e+00 - val_loss: 0.0943 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0943 - accuracy: 0.0000e+00 - val_loss: 0.0940 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0940 - accuracy: 0.0000e+00 - val_loss: 0.0937 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0937 - accuracy: 0.0000e+00 - val_loss: 0.0935 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0935 - accuracy: 0.0000e+00 - val_loss: 0.0933 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0933 - accuracy: 0.0000e+00 - val_loss: 0.0932 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0932 - accuracy: 0.0000e+00 - val_loss: 0.0930 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0931 - accuracy: 0.0000e+00 - val_loss: 0.0930 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0930 - accuracy: 0.0000e+00 - val_loss: 0.0929 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0929 - accuracy: 0.0000e+00 - val_loss: 0.0928 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0929 - accuracy: 0.0000e+00 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0928 - accuracy: 0.0000e+00 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0928 - accuracy: 0.0000e+00 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0928 - accuracy: 0.0000e+00 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0928 - accuracy: 0.0000e+00 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0927 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0927 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0926 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.0926 - accuracy: 0.0000e+00 - val_loss: 0.0925 - val_accuracy: 0.0000e+00
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 4)]          0           []
#
#  tf.__operators__.getitem_8 (Sl  (None, 2)           0           ['input_5[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_9 (Sl  (None, 2)           0           ['input_5[0][0]']
#  icingOpLambda)
#
#  sequential_4 (Sequential)      (None, 1)            2751        ['tf.__operators__.getitem_8[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_9[0][0
#                                                                  ]']
#
#  tf.stack_4 (TFOpLambda)        (None, 2, 1)         0           ['sequential_4[0][0]',
#                                                                   'sequential_4[1][0]']
#
# ==================================================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: training-toy-version3a-training-output/model-sf-2.0/assets
#
#
#  =============== Training with SF =  4.0
#
#
# Epoch 1/50
# 977/977 [==============================] - 5s 4ms/step - loss: 0.7247 - accuracy: 0.0000e+00 - val_loss: 0.1600 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1321 - accuracy: 0.0000e+00 - val_loss: 0.1257 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1243 - accuracy: 0.0000e+00 - val_loss: 0.1231 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1223 - accuracy: 0.0000e+00 - val_loss: 0.1217 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1213 - accuracy: 0.0000e+00 - val_loss: 0.1208 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1204 - accuracy: 0.0000e+00 - val_loss: 0.1200 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1197 - accuracy: 0.0000e+00 - val_loss: 0.1193 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1191 - accuracy: 0.0000e+00 - val_loss: 0.1188 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1186 - accuracy: 0.0000e+00 - val_loss: 0.1182 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1181 - accuracy: 0.0000e+00 - val_loss: 0.1179 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1178 - accuracy: 0.0000e+00 - val_loss: 0.1176 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1175 - accuracy: 0.0000e+00 - val_loss: 0.1173 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1173 - accuracy: 0.0000e+00 - val_loss: 0.1171 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1171 - accuracy: 0.0000e+00 - val_loss: 0.1169 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1169 - accuracy: 0.0000e+00 - val_loss: 0.1168 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1168 - accuracy: 0.0000e+00 - val_loss: 0.1167 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1167 - accuracy: 0.0000e+00 - val_loss: 0.1166 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1166 - accuracy: 0.0000e+00 - val_loss: 0.1166 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1166 - accuracy: 0.0000e+00 - val_loss: 0.1165 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1165 - accuracy: 0.0000e+00 - val_loss: 0.1164 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1165 - accuracy: 0.0000e+00 - val_loss: 0.1164 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1165 - accuracy: 0.0000e+00 - val_loss: 0.1164 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1164 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1164 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1163 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1163 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 977/977 [==============================] - 4s 4ms/step - loss: 0.1162 - accuracy: 0.0000e+00 - val_loss: 0.1162 - val_accuracy: 0.0000e+00
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 4)]          0           []
#
#  tf.__operators__.getitem_10 (S  (None, 2)           0           ['input_6[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_11 (S  (None, 2)           0           ['input_6[0][0]']
#  licingOpLambda)
#
#  sequential_5 (Sequential)      (None, 1)            2751        ['tf.__operators__.getitem_10[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  tf.stack_5 (TFOpLambda)        (None, 2, 1)         0           ['sequential_5[0][0]',
#                                                                   'sequential_5[1][0]']
#
# ==================================================================================================
# Total params: 2,751
# Trainable params: 2,751
# Non-trainable params: 0
# __________________________________________________________________________________________________
# INFO:tensorflow:Assets written to: training-toy-version3a-training-output/model-sf-4.0/assets
# CPU times: user 29min 24s, sys: 2min 56s, total: 32min 21s
# Wall time: 19min 31s

# %%
preds = []

for sfi in range(0, num_sf) :
    
    preds.append( model_sf_array[sfi].predict( X_test, batch_size=1024 ) )
# Out:
# 489/489 [==============================] - 0s 703us/step
# 489/489 [==============================] - 0s 683us/step
# 489/489 [==============================] - 0s 689us/step
# 489/489 [==============================] - 0s 687us/step
# 489/489 [==============================] - 0s 659us/step
# 489/489 [==============================] - 0s 685us/step

# %%
fig,ax = plt.subplots(num_sf,4,figsize=(15,18))

plotrange = 0

if plotrange == 0:

    plot_xmin = -1.1
    plot_xmax = 1.1

    plot_ymin = -1.6
    plot_ymax = 1.6


if plotrange == 1:
    
    plot_xmin = -3
    plot_xmax = 3

    plot_ymin = -3.6
    plot_ymax = 3.6



for sfi in range(0, num_sf) :

    ax[sfi][0].hist2d( Y_test[:,0], preds[sfi][:,0][Y_test>-9], bins=[80,80], 
                      range=([plot_xmin, plot_xmax],[plot_ymin, plot_ymax]))
    ax[sfi][1].hist2d( Y_test[:,0], preds[sfi][:,1][Y_test>-9], bins=[80,80],
                      range=([plot_xmin, plot_xmax],[plot_ymin, plot_ymax]))
    ax[sfi][2].hist2d( preds[sfi][:,0][Y_test>-9], preds[sfi][:,1][Y_test>-9], bins=[80,80], 
                      range=([plot_xmin, plot_xmax],[plot_ymin, plot_ymax]))
    ax[sfi][3].hist( preds[sfi][:,1], bins=80, range=[plot_xmin, plot_xmax])

    ax[sfi][0].plot( [-1.,1.],[-1.,1.], color="red")
    ax[sfi][1].plot( [-1.,1.],[-1.,1.], color="red")
    ax[sfi][2].plot( [-1.,1.],[-1.,1.], color="red")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(num_sf,4,figsize=(20,20))

plotxmin = -3.0
plotxmax = 3.0

plotymin = -3.1
plotymax = 3.1

for sfi in range(0, num_sf) :

    ax[sfi][0].hist2d( X_test[:,0], preds[sfi][:,0][Y_test>-9], bins=[180,180], range=([plotxmin, plotxmax],[plotymin, plotymax]))
    ax[sfi][1].hist2d( X_test[:,1], preds[sfi][:,0][Y_test>-9], bins=[180,180], range=([plotxmin, plotxmax],[plotymin, plotymax]))
    ax[sfi][2].hist2d( X_test[:,2], preds[sfi][:,1][Y_test>-9], bins=[180,180], range=([plotxmin, plotxmax],[plotymin, plotymax]))
    ax[sfi][3].hist2d( X_test[:,3], preds[sfi][:,1][Y_test>-9], bins=[180,180], range=([plotxmin, plotxmax],[plotymin, plotymax]))



plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Correlation analysis between input features and NN output

# %%
def calc_core_correlation( a, b ) -> float :
    
    nevts = np.shape(a)[0]
    
    asum = 0
    bsum = 0
    absum = 0
    aasum = 0
    bbsum = 0

    npass = 0

    for i in range(0,nevts) :
        aval = a[i]
        bval = b[i]
        if ( aval > 1 ) : continue
        if ( bval > 1 ) : continue
        if ( aval < -1 ) : continue
        if ( bval < -1 ) : continue
        #if ( i < 20 ) : print( "a = %7.3f  b = %7.3f" % (aval, bval))
        asum = asum + aval
        bsum = bsum + bval
        absum = absum + aval*bval
        aasum = aasum + aval*aval
        bbsum = bbsum + bval*bval
        npass = npass + 1

    avea = asum / npass
    aveb = bsum / npass

    aveab = absum / npass
    aveaa = aasum / npass
    avebb = bbsum / npass

    arms = np.sqrt( aveaa - avea*avea )
    brms = np.sqrt( avebb - aveb*aveb )

    rho =  ( aveab - avea*aveb ) / (arms*brms)

    #print("  number in sums: %d" % npass )
    #print("  a mean = %7.3f , b mean = %7.3f" % (avea, aveb))
    #print("  a rms = %7.3f, b rms = %7.3f" % (arms, brms))
    #print("  rho = %7.3f" % rho )
    
    return rho

# %%
rho_z0_nnz_vals = []
rho_z1_nnz_vals = []

rho_x0_nnx_vals = []
rho_x1_nnx_vals = []




for sfi in range(0, num_sf) :

    b = preds[sfi][:,0]
    
    a = X_test[:,0]
    rho_z0_nnz = calc_core_correlation( a, b )
    rho_z0_nnz_vals.append(rho_z0_nnz)
    
    a = X_test[:,1]
    rho_z1_nnz = calc_core_correlation( a, b )
    rho_z1_nnz_vals.append(rho_z1_nnz)

    b = preds[sfi][:,1]
    
    a = X_test[:,2]
    rho_x0_nnx = calc_core_correlation( a, b )
    rho_x0_nnx_vals.append(rho_x0_nnx)
    
    a = X_test[:,3]
    rho_x1_nnx = calc_core_correlation( a, b )
    rho_x1_nnx_vals.append(rho_x1_nnx)
    
    print( " sfi %d   %4.1f :  rho(z0,nnz) = %6.3f   rho(z1,nnz) = %6.3f    rho(x0,nnx) = %6.3f    rho(x1,nnx) = %6.3f"
          % ( sfi, sf_val[sfi], rho_z0_nnz, rho_z1_nnz, rho_x0_nnx, rho_x1_nnx ) )
# Out:
#  sfi 0    0.0 :  rho(z0,nnz) =  0.762   rho(z1,nnz) =  0.999    rho(x0,nnx) =  0.635    rho(x1,nnx) =  0.999
#  sfi 1    0.2 :  rho(z0,nnz) =  0.846   rho(z1,nnz) =  0.969    rho(x0,nnx) =  0.792    rho(x1,nnx) =  0.913
#  sfi 2    0.6 :  rho(z0,nnz) =  0.915   rho(z1,nnz) =  0.915    rho(x0,nnx) =  0.882    rho(x1,nnx) =  0.824
#  sfi 3    1.0 :  rho(z0,nnz) =  0.946   rho(z1,nnz) =  0.881    rho(x0,nnx) =  0.924    rho(x1,nnx) =  0.776
#  sfi 4    2.0 :  rho(z0,nnz) =  0.975   rho(z1,nnz) =  0.836    rho(x0,nnx) =  0.965    rho(x1,nnx) =  0.717
#  sfi 5    4.0 :  rho(z0,nnz) =  0.990   rho(z1,nnz) =  0.806    rho(x0,nnx) =  0.985    rho(x1,nnx) =  0.679

# %% [markdown]
# ## Generate new nominal data and alternate detector response data at specific mu

# %%
mu_val = 1.0
ngen = 1000000

alt_x0_sig = 1.4 * x0_sig
alt_x1_sig = 1.4 * x1_sig

#alt_x0_mean = 0.4 * x0_sig
alt_x0_mean = 0.0
alt_x1_mean = 0.4 * x1_sig



fixedmu_z0 = np.random.normal( mu_val, z0_sig, ngen )
fixedmu_z1 = np.random.normal( mu_val, z1_sig, ngen )


fixedmu_x0 = np.random.normal( fixedmu_z0, x0_sig )
fixedmu_x1 = np.random.normal( fixedmu_z1, x1_sig )

resfun_x0 = np.random.normal( 0., x0_sig, ngen )
resfun_x1 = np.random.normal( 0., x1_sig, ngen )

alt_resfun_x0 = np.random.normal( alt_x0_mean, alt_x0_sig, ngen )
alt_resfun_x1 = np.random.normal( alt_x1_mean, alt_x1_sig, ngen )

fixedmu_X = np.c_[
    fixedmu_z0,
    fixedmu_z1,
    fixedmu_x0,
    fixedmu_x1,
]

fixedmu_Xs = scalerX.transform( fixedmu_X )

fixedmu_preds = []

for sfi in range(0, num_sf) :
    
    fixedmu_preds.append( model_sf_array[sfi].predict( fixedmu_Xs, batch_size=1024 ) )
# Out:
# 977/977 [==============================] - 1s 689us/step
# 977/977 [==============================] - 1s 686us/step
# 977/977 [==============================] - 1s 697us/step
# 977/977 [==============================] - 1s 673us/step
# 977/977 [==============================] - 1s 681us/step
# 977/977 [==============================] - 1s 687us/step

# %%
print("")
print(" x0 resolution: nominal sigma %6.3f, alt sigma %6.3f,  alt mean %6.3f" % (x0_sig, alt_x0_sig, alt_x0_mean))
print(" x1 resolution: nominal sigma %6.3f, alt sigma %6.3f,  alt mean %6.3f" % (x1_sig, alt_x1_sig, alt_x1_mean))
print("")

alt_fixedmu_x0 = np.random.normal( fixedmu_z0 + alt_x0_mean, alt_x0_sig )
alt_fixedmu_x1 = np.random.normal( fixedmu_z1 + alt_x1_mean, alt_x1_sig )


alt_fixedmu_X = np.c_[
    fixedmu_z0,
    fixedmu_z1,
    alt_fixedmu_x0,
    alt_fixedmu_x1,
]

alt_fixedmu_Xs = scalerX.transform( alt_fixedmu_X )

alt_fixedmu_preds = []

for sfi in range(0, num_sf) :
    
    alt_fixedmu_preds.append( model_sf_array[sfi].predict( alt_fixedmu_Xs, batch_size=1024 ) )
# Out:
#  x0 resolution: nominal sigma  0.100, alt sigma  0.140,  alt mean  0.000
#  x1 resolution: nominal sigma  0.500, alt sigma  0.700,  alt mean  0.200
#
# 977/977 [==============================] - 1s 699us/step
# 977/977 [==============================] - 1s 682us/step
# 977/977 [==============================] - 1s 697us/step
# 977/977 [==============================] - 1s 688us/step
# 977/977 [==============================] - 1s 659us/step
# 977/977 [==============================] - 1s 712us/step

# %%
fig,ax = plt.subplots(2,4,figsize=(18,8))


ax[0][0].hist( fixedmu_X[:,0], bins=80, density=True )
ax[0][1].hist( fixedmu_X[:,1], bins=80, density=True)
ax[0][2].hist( fixedmu_X[:,2], bins=80, density=True)
ax[0][3].hist( fixedmu_X[:,3], bins=80, density=True)

ax[1][0].hist( fixedmu_Xs[:,0], bins=80, density=True)
ax[1][1].hist( fixedmu_Xs[:,1], bins=80, density=True)
ax[1][2].hist( fixedmu_Xs[:,2], bins=80, density=True)
ax[1][3].hist( fixedmu_Xs[:,3], bins=80, density=True)



ax[0][0].hist( alt_fixedmu_X[:,0], bins=80, alpha=0.7, density=True)
ax[0][1].hist( alt_fixedmu_X[:,1], bins=80, alpha=0.7, density=True)
ax[0][2].hist( alt_fixedmu_X[:,2], bins=80, alpha=0.7, density=True)
ax[0][3].hist( alt_fixedmu_X[:,3], bins=80, alpha=0.7, density=True)

ax[1][0].hist( alt_fixedmu_Xs[:,0], bins=80, alpha=0.7, density=True)
ax[1][1].hist( alt_fixedmu_Xs[:,1], bins=80, alpha=0.7, density=True)
ax[1][2].hist( alt_fixedmu_Xs[:,2], bins=80, alpha=0.7, density=True)
ax[1][3].hist( alt_fixedmu_Xs[:,3], bins=80, alpha=0.7, density=True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(2,num_sf,figsize=(18,8))

nom_rms_vals = []
alt_rms_vals = []

nom_bias_vals = []
alt_bias_vals = []


for sfi in range(0, num_sf) :

    ax[0][sfi].hist( fixedmu_preds[sfi][:,1], bins=80, range=[-2.5,2.5], density=True )
    ax[0][sfi].hist( alt_fixedmu_preds[sfi][:,1], bins=80, range=[-2.5,2.5], alpha=0.6, density=True)
    
    ax[1][sfi].hist( alt_fixedmu_preds[sfi][:,1], bins=80, range=[-2.5,2.5], density=True)
    
    mean = np.mean( fixedmu_preds[sfi][:,1] )
    rms = np.sqrt( np.mean( np.square( fixedmu_preds[sfi][:,1] - mean)))
    nom_rms_vals.append( rms )
    nom_bias_vals.append( mean - mu_val )
    
    alt_mean = np.mean( alt_fixedmu_preds[sfi][:,1] )
    alt_rms = np.sqrt( np.mean( np.square( alt_fixedmu_preds[sfi][:,1] - alt_mean)))
    alt_rms_vals.append( alt_rms )
    alt_bias_vals.append( alt_mean - mu_val )
 
    print("  nom SF %d :  mean = %7.3f, rms = %7.3f" % (sfi, mean, rms))
    print("  alt SF %d :  mean = %7.3f, rms = %7.3f\n" % (sfi, alt_mean, alt_rms))
# Out:
#   nom SF 0 :  mean =   0.965, rms =   0.471
#   alt SF 0 :  mean =   1.148, rms =   0.650
#
#   nom SF 1 :  mean =   0.970, rms =   0.373
#   alt SF 1 :  mean =   1.087, rms =   0.468
#
#   nom SF 2 :  mean =   0.988, rms =   0.363
#   alt SF 2 :  mean =   1.068, rms =   0.422
#
#   nom SF 3 :  mean =   0.992, rms =   0.378
#   alt SF 3 :  mean =   1.054, rms =   0.420
#
#   nom SF 4 :  mean =   0.995, rms =   0.409
#   alt SF 4 :  mean =   1.036, rms =   0.434
#
#   nom SF 5 :  mean =   0.990, rms =   0.433
#   alt SF 5 :  mean =   1.016, rms =   0.450

# %%
fig,ax = plt.subplots(3,2,figsize=(10,10))

plt.subplots_adjust( hspace=0.30)
plt.subplots_adjust( wspace=0.25)

nbins=60



ax[0][0].hist( fixedmu_z0, bins=nbins, range=[-2+mu_val,2+mu_val], density=True )
ax[0][1].hist( fixedmu_z1, bins=nbins, range=[-2+mu_val,2+mu_val], density=True )

ax[1][0].hist( resfun_x0, bins=nbins, range=[-2.,2.], density=True, label='Res. A' )
ax[1][1].hist( resfun_x1, bins=nbins, range=[-2.,2.], density=True, label='Res. A' )

ax[1][0].hist( alt_resfun_x0, bins=nbins, range=[-2.,2.], density=True, alpha=0.6, label='Res. B' )
ax[1][1].hist( alt_resfun_x1, bins=nbins, range=[-2.,2.], density=True, alpha=0.6, label='Res. B' )


ax[2][0].hist( fixedmu_x0, bins=nbins, range=[-2+mu_val,2+mu_val], density=True, label='Res. A' )
ax[2][1].hist( fixedmu_x1, bins=nbins, range=[-2+mu_val,2+mu_val], density=True, label='Res. A' )

ax[2][0].hist( alt_fixedmu_x0, bins=nbins, range=[-2+mu_val,2+mu_val], density=True, alpha=0.6, label='Res. B' )
ax[2][1].hist( alt_fixedmu_x1, bins=nbins, range=[-2+mu_val,2+mu_val], density=True, alpha=0.6, label='Res. B' )





xlabel_fontsize = 15
ylabel_fontsize = 13

ax[0][0].set_xlabel( 'Particle feature $z_0$', fontsize=xlabel_fontsize )
ax[0][1].set_xlabel( 'Particle feature $z_1$', fontsize=xlabel_fontsize )

ax[1][0].set_xlabel( '$x_0 - z_0$', fontsize=xlabel_fontsize )
ax[1][1].set_xlabel( '$x_1 - z_1$', fontsize=xlabel_fontsize )

ax[2][0].set_xlabel( 'Detector feature $x_0$', fontsize=xlabel_fontsize )
ax[2][1].set_xlabel( 'Detector feature $x_1$', fontsize=xlabel_fontsize )



ax[0][0].set_ylabel( 'Normalized entries', fontsize=ylabel_fontsize )
ax[0][1].set_ylabel( 'Normalized entries', fontsize=ylabel_fontsize )

ax[1][0].set_ylabel( 'Normalized entries', fontsize=ylabel_fontsize )
ax[1][1].set_ylabel( 'Normalized entries', fontsize=ylabel_fontsize )

ax[2][0].set_ylabel( 'Normalized entries', fontsize=ylabel_fontsize )
ax[2][1].set_ylabel( 'Normalized entries', fontsize=ylabel_fontsize )


ax[0][0].text( -0.7, 0.80*ax[0][0].get_ylim()[1], '$\mu = %.0f$' % mu_val, fontsize=14 )
ax[0][1].text( -0.7, 0.80*ax[0][1].get_ylim()[1], '$\mu = %.0f$' % mu_val, fontsize=14 )

ax[2][0].text( -0.7, 0.80*ax[2][0].get_ylim()[1], '$\mu = %.0f$' % mu_val, fontsize=14 )
ax[2][1].text( -0.7, 0.80*ax[2][1].get_ylim()[1], '$\mu = %.0f$' % mu_val, fontsize=14 )




ax[1][0].legend( loc='best', fontsize=12 )
ax[1][1].legend( loc='best', fontsize=12 )

ax[2][0].legend( loc='best', fontsize=12 )
ax[2][1].legend( loc='best', fontsize=12 )



plt.savefig( 'toy-regression-features.png', bbox_inches='tight' )
plt.savefig( 'toy-regression-features.pdf', bbox_inches='tight' )


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(1,3,figsize=(14,4))

plt.subplots_adjust( wspace=0.45)

plt.rc( 'xtick', labelsize=13)
plt.rc( 'ytick', labelsize=13)


ax[0].plot( sf_val, rho_x0_nnx_vals, marker="o", label='$x_0$' )
ax[0].plot( sf_val, rho_x1_nnx_vals, marker="^", label='$x_1$' )

ax[0].set_xlim(-0.5,4.5)
ax[0].set_ylim(0.60,1.15)



ax[1].plot( sf_val, nom_rms_vals, marker="o", label='Res A' )
ax[1].set_xlim(-0.5,4.5)
#ax[1].set_ylim(0.0,0.47)
ax[1].set_ylim(0.0,0.75)

ax[1].plot( sf_val, alt_rms_vals, marker="^", label='Res B' )





ax[2].plot( sf_val, nom_bias_vals, marker="o", label='Res A' )
ax[2].set_xlim(-0.5,4.5)
#ax[2].set_ylim(-0.03,0.13)
ax[2].set_ylim(-0.05,0.20)

ax[2].plot( sf_val, alt_bias_vals, marker="^", label='Res B' )





xlabel_fontsize = 17
ylabel_fontsize = 17


ax[0].set_xlabel( '$\lambda$', fontsize=xlabel_fontsize )
ax[1].set_xlabel( '$\lambda$', fontsize=xlabel_fontsize )
ax[2].set_xlabel( '$\lambda$', fontsize=xlabel_fontsize )


ax[0].set_ylabel( 'Correlation: $\\rho(x,f)$', fontsize=ylabel_fontsize )
ax[1].set_ylabel( 'Resolution: RMS(f)', fontsize=ylabel_fontsize )
ax[2].set_ylabel( 'Bias: $<f-\mu>$', fontsize=ylabel_fontsize )

ax[0].legend( loc='best', fontsize=14 )
ax[1].legend( loc='best', fontsize=14 )
ax[2].legend( loc='best', fontsize=14 )


plt.savefig( 'toy-regression-resolution.png', bbox_inches='tight' )
plt.savefig( 'toy-regression-resolution.pdf', bbox_inches='tight' )


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
