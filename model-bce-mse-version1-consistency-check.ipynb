# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.colors import LogNorm
from matplotlib import rc
from numpy import inf
import os
import sys
from IPython import display


#-- this selects the first GPU
os.environ['CUDA_VISIBLE_DEVICES']="0"

from os import listdir

from pickle import dump
from pickle import load

import uproot3

import matplotlib as mpl

from datetime import datetime
import subprocess

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.losses import Loss, BinaryCrossentropy
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


from tensorflow.python.client import device_lib

from pickle import dump


#has_gpu = False

has_gpu = True



from tensorflow.keras.callbacks import EarlyStopping
earlystopping = EarlyStopping(patience=20,
               verbose=True,
               restore_best_weights=True)

import os

print(tf.config.list_physical_devices())

if has_gpu :
    #os.environ['CUDA_VISIBLE_DEVICES']="0"
    physical_devices = tf.config.list_physical_devices('GPU') 
    tf.config.experimental.set_memory_growth(physical_devices[0], True)


    print("\n\n printing physical devbices from tf.config.list_physical_devices\n\n")
    print(physical_devices)

    devices = device_lib.list_local_devices()

    print("\n\n printing devices from device_lib.list_local_devices\n\n")
    print(devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
#
#  printing physical devbices from tf.config.list_physical_devices
#
#
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
#
#  printing devices from device_lib.list_local_devices
#
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 6582578136170971110
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 23048290304
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 499341954365687549
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]
# 2023-08-13 11:10:58.834029: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:58.852023: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:58.852263: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:58.855732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:58.855926: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:58.856095: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:59.268730: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:59.268948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:59.269122: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:10:59.269275: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 21980 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6

# %%
training_name = 'training-bce-mse-version1c'

testmode = False
testmode = True

run_training = True
#run_training = False


#use_weights = True
use_weights = False

if run_training :
    
    try:
        os.mkdir( '%s-training-output' % training_name )
    except:
        print('\n  Dir %s-training-output already exists\n\n' % training_name )
        #print('\n\n HALTING EXECUTION \n\n')
        #sys.exit()

        

#--- Hyperparameter settings.


    
#-- settings for nominal running
#max_events =   120000
#max_events =   300000
#max_events =   600000
max_events =  1000000
#max_events =  3000000

#max_events = 15000000
#max_events = 1e9


learning_rate_setval = 5e-5
batch_size_setval = 512
max_epochs = 5000
amsgrad_setval = False
patience_setval = 40
hp_lambda = 1.0

if testmode :

#-- settings for quick syntax checking runthrough
    max_events =   600000
    learning_rate_setval = 1e-3
    batch_size_setval = 4096
    max_epochs = 200





#input_file_rapgap = '/data/owen/DIS-reco/h1-2021-10-14-v5a/all-h1-rapgap.root'
#input_file_django = '/data/owen/DIS-reco/h1-2021-10-14-v5a/all-h1-django.root'

#input_file_rapgap = '/data/owen/DIS-reco/h1-2023-06-23-v6c/test-rapgap.root'
#input_file_django = '/data/owen/DIS-reco/h1-2023-06-23-v6c/test-django.root'

input_file_rapgap = '/data/owen/DIS-reco/h1-2023-06-23-v6c/all-h1-rapgap.root'
input_file_django = '/data/owen/DIS-reco/h1-2023-06-23-v6c/all-h1-django.root'


output_dir = '%s-training-output' % training_name

parfile_name = '%s/setup.txt' % output_dir

if run_training :

    parfile = open( parfile_name,'w')

    parfile.write('%s\n' % datetime.now() )
    parfile.write('training_name : %s\n' % training_name )
    parfile.write('hp_lambda : %s\n' % hp_lambda )
    parfile.write('input_file_rapgap : %s\n' % input_file_rapgap )
    parfile.write('input_file_django : %s\n' % input_file_django )
    parfile.write('max_events : %d\n' % max_events )
    parfile.write('learning_rate_setval_reg : %g\n' % learning_rate_setval )
    parfile.write('batch_size_setval : %d\n' % batch_size_setval )
    parfile.write('max_epochs : %d\n' % max_epochs )
    parfile.write('amsgrad_setval : %g\n' % amsgrad_setval )
    parfile.write('patience_setval : %g\n' % patience_setval )
    parfile.write('use_weights : %d\n' % use_weights )

    parfile.close()

print('\n\n--- Training parameters file: %s\n' % parfile_name )
print( subprocess.getoutput('cat %s' % parfile_name ) )
print('\n\n')
# Out:
#   Dir training-bce-mse-version1c-training-output already exists
#
#
#
#
# --- Training parameters file: training-bce-mse-version1c-training-output/setup.txt
#
# 2023-08-13 11:10:59.276598
# training_name : training-bce-mse-version1c
# hp_lambda : 1.0
# input_file_rapgap : /data/owen/DIS-reco/h1-2023-06-23-v6c/all-h1-rapgap.root
# input_file_django : /data/owen/DIS-reco/h1-2023-06-23-v6c/all-h1-django.root
# max_events : 600000
# learning_rate_setval_reg : 0.001
# batch_size_setval : 4096
# max_epochs : 200
# amsgrad_setval : 0
# patience_setval : 40
# use_weights : 0

# %%
# %%time


ur_file_rapgap = uproot3.open(input_file_rapgap)

print (ur_file_rapgap.keys()) 
ur_tree_rapgap = ur_file_rapgap['Rapgap/minitree']
print(ur_tree_rapgap)
ur_tree_rapgap.show()


#pandas_df   =  ur_tree.pandas.df(['*'], entrystop=max_events,flatten=True)

pandas_df_rapgap   =  ur_tree_rapgap.pandas.df(
    ['has_isr','has_fsr',
     'tower_sum_40','n_towers_40', 
     'eta_pho_closest_to_ebeam','e_pho_closest_to_ebeam', 'phi_pho_closest_to_ebeam',
     'obs_x', 'obs_y', 'obs_Q2',
     'from_tlv_gen_Q2','from_tlv_gen_x','from_tlv_gen_y',
     'obs_e_e','obs_e_pz','obs_e_pt','obs_e_phi',
     'obs_hfs_e','obs_hfs_pz','obs_hfs_pt','obs_hfs_phi',
     'obs_dphi',
     'Empz', 'obs_e_trk_e',
     'beam_e_e', 'wgt',
     'gen_e_e', 'gen_e_pz', 'gen_e_pt', 'gen_e_eta', 'gen_e_phi',
     'obs_e_eta',
     'gen_hfs_e', 'gen_hfs_pz', 'gen_hfs_pt', 'gen_hfs_eta',
     'gen_hfs_etacut_e','gen_hfs_etacut_pz','gen_hfs_etacut_pt','gen_hfs_etacut_eta', 'gen_hfs_etacut_phi',
     'obs_hfs_eta',
    ],
    entrystop=max_events,flatten=True)

print('\n\n Number of entries in pandas_df:  %d ' % pandas_df_rapgap.shape[0] )
# Out:
# [b'Rapgap;1']
# <TTree b'minitree' at 0x7f8898b3c070>
# wgt                        (no streamer)              asdtype('>f4')
# Empz                       (no streamer)              asdtype('>f4')
# from_tlv_gen_Q2            (no streamer)              asdtype('>f4')
# from_tlv_gen_x             (no streamer)              asdtype('>f4')
# from_tlv_gen_y             (no streamer)              asdtype('>f4')
# beam_e_e                   (no streamer)              asdtype('>f4')
# beam_p_e                   (no streamer)              asdtype('>f4')
# has_isr                    (no streamer)              asdtype('int8')
# has_fsr                    (no streamer)              asdtype('int8')
# gen_e_e                    (no streamer)              asdtype('>f4')
# gen_e_pz                   (no streamer)              asdtype('>f4')
# gen_e_pt                   (no streamer)              asdtype('>f4')
# gen_e_phi                  (no streamer)              asdtype('>f4')
# gen_e_eta                  (no streamer)              asdtype('>f4')
# gen_hfs_e                  (no streamer)              asdtype('>f4')
# gen_hfs_pz                 (no streamer)              asdtype('>f4')
# gen_hfs_pt                 (no streamer)              asdtype('>f4')
# gen_hfs_phi                (no streamer)              asdtype('>f4')
# gen_hfs_eta                (no streamer)              asdtype('>f4')
# gen_hfs_etacut_e           (no streamer)              asdtype('>f4')
# gen_hfs_etacut_pz          (no streamer)              asdtype('>f4')
# gen_hfs_etacut_pt          (no streamer)              asdtype('>f4')
# gen_hfs_etacut_phi         (no streamer)              asdtype('>f4')
# gen_hfs_etacut_eta         (no streamer)              asdtype('>f4')
# gen_dphi                   (no streamer)              asdtype('>f4')
# obs_e_e                    (no streamer)              asdtype('>f4')
# obs_e_pz                   (no streamer)              asdtype('>f4')
# obs_e_pt                   (no streamer)              asdtype('>f4')
# obs_e_phi                  (no streamer)              asdtype('>f4')
# obs_e_eta                  (no streamer)              asdtype('>f4')
# obs_hfs_e                  (no streamer)              asdtype('>f4')
# obs_hfs_pz                 (no streamer)              asdtype('>f4')
# obs_hfs_pt                 (no streamer)              asdtype('>f4')
# obs_hfs_phi                (no streamer)              asdtype('>f4')
# obs_hfs_eta                (no streamer)              asdtype('>f4')
# obs_dphi                   (no streamer)              asdtype('>f4')
# obs_x                      (no streamer)              asdtype("('>f4', (9,))")
# obs_y                      (no streamer)              asdtype("('>f4', (9,))")
# obs_Q2                     (no streamer)              asdtype("('>f4', (9,))")
# phi_pho_closest_to_ebeam   (no streamer)              asdtype('>f4')
# eta_pho_closest_to_ebeam   (no streamer)              asdtype('>f4')
# e_pho_closest_to_ebeam     (no streamer)              asdtype('>f4')
# tower_sum_40               (no streamer)              asdtype('>f4')
# n_towers_40                (no streamer)              asdtype('>i4')
# obs_e_trk_e                (no streamer)              asdtype('>f4')
# obs_e_trk_eta              (no streamer)              asdtype('>f4')
# obs_e_trk_phi              (no streamer)              asdtype('>f4')
#
#
#  Number of entries in pandas_df:  600000
# CPU times: user 765 ms, sys: 81 ms, total: 846 ms
# Wall time: 844 ms

# %%
# %%time


ur_file_django = uproot3.open(input_file_django)

print (ur_file_django.keys()) 
ur_tree_django = ur_file_django['Django/minitree']
print(ur_tree_django)
ur_tree_django.show()


#pandas_df   =  ur_tree.pandas.df(['*'], entrystop=max_events,flatten=True)

pandas_df_django   =  ur_tree_django.pandas.df(
    ['has_isr','has_fsr',
     'tower_sum_40','n_towers_40', 
     'eta_pho_closest_to_ebeam','e_pho_closest_to_ebeam', 'phi_pho_closest_to_ebeam',
     'obs_x', 'obs_y', 'obs_Q2',
     'from_tlv_gen_Q2','from_tlv_gen_x','from_tlv_gen_y',
     'obs_e_e','obs_e_pz','obs_e_pt','obs_e_phi',
     'obs_hfs_e','obs_hfs_pz','obs_hfs_pt','obs_hfs_phi',
     'obs_dphi',
     'Empz', 'obs_e_trk_e',
     'beam_e_e', 'wgt',
     'gen_e_e', 'gen_e_pz', 'gen_e_pt', 'gen_e_eta', 'gen_e_phi',
     'obs_e_eta',
     'gen_hfs_e', 'gen_hfs_pz', 'gen_hfs_pt', 'gen_hfs_eta',
     'gen_hfs_etacut_e','gen_hfs_etacut_pz','gen_hfs_etacut_pt','gen_hfs_etacut_eta', 'gen_hfs_etacut_phi',
     'obs_hfs_eta',
    ],
    entrystop=max_events,flatten=True)

print('\n\n Number of entries in pandas_df:  %d ' % pandas_df_django.shape[0] )
# Out:
# [b'Django;1']
# <TTree b'minitree' at 0x7f8898b20730>
# wgt                        (no streamer)              asdtype('>f4')
# Empz                       (no streamer)              asdtype('>f4')
# from_tlv_gen_Q2            (no streamer)              asdtype('>f4')
# from_tlv_gen_x             (no streamer)              asdtype('>f4')
# from_tlv_gen_y             (no streamer)              asdtype('>f4')
# beam_e_e                   (no streamer)              asdtype('>f4')
# beam_p_e                   (no streamer)              asdtype('>f4')
# has_isr                    (no streamer)              asdtype('int8')
# has_fsr                    (no streamer)              asdtype('int8')
# gen_e_e                    (no streamer)              asdtype('>f4')
# gen_e_pz                   (no streamer)              asdtype('>f4')
# gen_e_pt                   (no streamer)              asdtype('>f4')
# gen_e_phi                  (no streamer)              asdtype('>f4')
# gen_e_eta                  (no streamer)              asdtype('>f4')
# gen_hfs_e                  (no streamer)              asdtype('>f4')
# gen_hfs_pz                 (no streamer)              asdtype('>f4')
# gen_hfs_pt                 (no streamer)              asdtype('>f4')
# gen_hfs_phi                (no streamer)              asdtype('>f4')
# gen_hfs_eta                (no streamer)              asdtype('>f4')
# gen_hfs_etacut_e           (no streamer)              asdtype('>f4')
# gen_hfs_etacut_pz          (no streamer)              asdtype('>f4')
# gen_hfs_etacut_pt          (no streamer)              asdtype('>f4')
# gen_hfs_etacut_phi         (no streamer)              asdtype('>f4')
# gen_hfs_etacut_eta         (no streamer)              asdtype('>f4')
# gen_dphi                   (no streamer)              asdtype('>f4')
# obs_e_e                    (no streamer)              asdtype('>f4')
# obs_e_pz                   (no streamer)              asdtype('>f4')
# obs_e_pt                   (no streamer)              asdtype('>f4')
# obs_e_phi                  (no streamer)              asdtype('>f4')
# obs_e_eta                  (no streamer)              asdtype('>f4')
# obs_hfs_e                  (no streamer)              asdtype('>f4')
# obs_hfs_pz                 (no streamer)              asdtype('>f4')
# obs_hfs_pt                 (no streamer)              asdtype('>f4')
# obs_hfs_phi                (no streamer)              asdtype('>f4')
# obs_hfs_eta                (no streamer)              asdtype('>f4')
# obs_dphi                   (no streamer)              asdtype('>f4')
# obs_x                      (no streamer)              asdtype("('>f4', (9,))")
# obs_y                      (no streamer)              asdtype("('>f4', (9,))")
# obs_Q2                     (no streamer)              asdtype("('>f4', (9,))")
# phi_pho_closest_to_ebeam   (no streamer)              asdtype('>f4')
# eta_pho_closest_to_ebeam   (no streamer)              asdtype('>f4')
# e_pho_closest_to_ebeam     (no streamer)              asdtype('>f4')
# tower_sum_40               (no streamer)              asdtype('>f4')
# n_towers_40                (no streamer)              asdtype('>i4')
# obs_e_trk_e                (no streamer)              asdtype('>f4')
# obs_e_trk_eta              (no streamer)              asdtype('>f4')
# obs_e_trk_phi              (no streamer)              asdtype('>f4')
#
#
#  Number of entries in pandas_df:  600000
# CPU times: user 772 ms, sys: 64.6 ms, total: 837 ms
# Wall time: 834 ms

# %%
pandas_df_rapgap.eval( 'obs_hfs_Empz = obs_hfs_e - obs_hfs_pz', inplace=True )
pandas_df_rapgap.eval( 'obs_e_Empz = obs_e_e - obs_e_pz', inplace=True )

pandas_df_rapgap.eval( 'obs_event_Empz = obs_hfs_Empz + obs_e_Empz', inplace=True )

pandas_df_rapgap.eval( 'rot_pt1 = 0.70710678 * obs_hfs_pt - 0.70710678 * obs_e_pt', inplace=True )
pandas_df_rapgap.eval( 'rot_pt2 = 0.70710678 * obs_hfs_pt + 0.70710678 * obs_e_pt', inplace=True )

pandas_df_rapgap.eval( 'rot_Empz1 = 0.70710678 * obs_hfs_Empz - 0.70710678 * obs_e_Empz', inplace=True )
pandas_df_rapgap.eval( 'rot_Empz2 = 0.70710678 * obs_hfs_Empz + 0.70710678 * obs_e_Empz', inplace=True )

pandas_df_rapgap.eval( 'gen_log_x = log(from_tlv_gen_x)', inplace=True )
pandas_df_rapgap.eval( 'gen_log_y = log(from_tlv_gen_y)', inplace=True )
pandas_df_rapgap.eval( 'gen_log_Q2 = log(from_tlv_gen_Q2)', inplace=True )

pandas_df_rapgap.eval( 'e_ecal_over_trk_ratio = tower_sum_40/obs_e_trk_e', inplace=True )
pandas_df_rapgap.eval( 'e_ecal_over_trk_ratio = (e_ecal_over_trk_ratio<4)*e_ecal_over_trk_ratio + (e_ecal_over_trk_ratio>4)*4', inplace=True )

pandas_df_rapgap.eval( 'dphi_pho_closest_to_ebeam = obs_e_phi - phi_pho_closest_to_ebeam', inplace=True )
pandas_df_rapgap.eval( 'dphi_pho_closest_to_ebeam = (abs(dphi_pho_closest_to_ebeam)<3.14159265)*(dphi_pho_closest_to_ebeam)+(dphi_pho_closest_to_ebeam>3.14159265)*(dphi_pho_closest_to_ebeam-2*3.14159265) + (dphi_pho_closest_to_ebeam<-3.14159265)*(dphi_pho_closest_to_ebeam+2*3.14159265)', inplace=True )
pandas_df_rapgap.eval( 'dphi_pho_closest_to_ebeam = (dphi_pho_closest_to_ebeam>0)*dphi_pho_closest_to_ebeam + (dphi_pho_closest_to_ebeam<0)*(dphi_pho_closest_to_ebeam+2*3.14159265)', inplace=True )
pandas_df_rapgap.eval( 'dphi_pho_closest_to_ebeam = (phi_pho_closest_to_ebeam!=0)*(dphi_pho_closest_to_ebeam)+(phi_pho_closest_to_ebeam==0)*(-1)', inplace=True )

pandas_df_rapgap.eval( 'e_pho_closest_to_ebeam = (e_pho_closest_to_ebeam<30)*e_pho_closest_to_ebeam + (e_pho_closest_to_ebeam>30)*30', inplace=True )

pandas_df_rapgap.eval( 'n_towers_40 = (n_towers_40<7)*n_towers_40 + (n_towers_40>=7)*7', inplace=True  )

pandas_df_rapgap.eval( 'has_norad = (has_isr==0) and (has_fsr==0)', inplace=True )

# %%
pandas_df_django.eval( 'obs_hfs_Empz = obs_hfs_e - obs_hfs_pz', inplace=True )
pandas_df_django.eval( 'obs_e_Empz = obs_e_e - obs_e_pz', inplace=True )

pandas_df_django.eval( 'obs_event_Empz = obs_hfs_Empz + obs_e_Empz', inplace=True )

pandas_df_django.eval( 'rot_pt1 = 0.70710678 * obs_hfs_pt - 0.70710678 * obs_e_pt', inplace=True )
pandas_df_django.eval( 'rot_pt2 = 0.70710678 * obs_hfs_pt + 0.70710678 * obs_e_pt', inplace=True )

pandas_df_django.eval( 'rot_Empz1 = 0.70710678 * obs_hfs_Empz - 0.70710678 * obs_e_Empz', inplace=True )
pandas_df_django.eval( 'rot_Empz2 = 0.70710678 * obs_hfs_Empz + 0.70710678 * obs_e_Empz', inplace=True )

pandas_df_django.eval( 'gen_log_x = log(from_tlv_gen_x)', inplace=True )
pandas_df_django.eval( 'gen_log_y = log(from_tlv_gen_y)', inplace=True )
pandas_df_django.eval( 'gen_log_Q2 = log(from_tlv_gen_Q2)', inplace=True )

pandas_df_django.eval( 'e_ecal_over_trk_ratio = tower_sum_40/obs_e_trk_e', inplace=True )
pandas_df_django.eval( 'e_ecal_over_trk_ratio = (e_ecal_over_trk_ratio<4)*e_ecal_over_trk_ratio + (e_ecal_over_trk_ratio>4)*4', inplace=True )

pandas_df_django.eval( 'dphi_pho_closest_to_ebeam = obs_e_phi - phi_pho_closest_to_ebeam', inplace=True )
pandas_df_django.eval( 'dphi_pho_closest_to_ebeam = (abs(dphi_pho_closest_to_ebeam)<3.14159265)*(dphi_pho_closest_to_ebeam)+(dphi_pho_closest_to_ebeam>3.14159265)*(dphi_pho_closest_to_ebeam-2*3.14159265) + (dphi_pho_closest_to_ebeam<-3.14159265)*(dphi_pho_closest_to_ebeam+2*3.14159265)', inplace=True )
pandas_df_django.eval( 'dphi_pho_closest_to_ebeam = (dphi_pho_closest_to_ebeam>0)*dphi_pho_closest_to_ebeam + (dphi_pho_closest_to_ebeam<0)*(dphi_pho_closest_to_ebeam+2*3.14159265)', inplace=True )
pandas_df_django.eval( 'dphi_pho_closest_to_ebeam = (phi_pho_closest_to_ebeam!=0)*(dphi_pho_closest_to_ebeam)+(phi_pho_closest_to_ebeam==0)*(-1)', inplace=True )

pandas_df_django.eval( 'e_pho_closest_to_ebeam = (e_pho_closest_to_ebeam<30)*e_pho_closest_to_ebeam + (e_pho_closest_to_ebeam>30)*30', inplace=True )

pandas_df_django.eval( 'n_towers_40 = (n_towers_40<7)*n_towers_40 + (n_towers_40>=7)*7', inplace=True  )

pandas_df_django.eval( 'has_norad = (has_isr==0) and (has_fsr==0)', inplace=True )

# %%
pandas_df_rapgap.eval( 'obs_ptbal = 1. - obs_e_pt / obs_hfs_pt', inplace=True )
pandas_df_rapgap.eval( 'obs_pzbal = 1. - (obs_hfs_Empz + obs_e_Empz)/2./beam_e_e', inplace=True )

# %%
pandas_df_django.eval( 'obs_ptbal = 1. - obs_e_pt / obs_hfs_pt', inplace=True )
pandas_df_django.eval( 'obs_pzbal = 1. - (obs_hfs_Empz + obs_e_Empz)/2./beam_e_e', inplace=True )

# %%
pandas_df_rapgap.eval( 'gen_dphi_etacut = (gen_e_phi - gen_hfs_etacut_phi) + ((gen_e_phi - gen_hfs_etacut_phi)<0)*2*3.14159 - ((gen_e_phi - gen_hfs_etacut_phi)>2*3.14159)*2*3.14159', inplace=True )

# %%
pandas_df_django.eval( 'gen_dphi_etacut = (gen_e_phi - gen_hfs_etacut_phi) + ((gen_e_phi - gen_hfs_etacut_phi)<0)*2*3.14159 - ((gen_e_phi - gen_hfs_etacut_phi)>2*3.14159)*2*3.14159', inplace=True )

# %% [markdown]
# ## Apply any event selection here.

# %%
pandas_df_rapgap = pandas_df_rapgap.query('Empz > 0')

pandas_df_rapgap = pandas_df_rapgap.query('obs_event_Empz > 46 and obs_event_Empz < 62')

pandas_df_rapgap = pandas_df_rapgap.query('obs_hfs_pt > 0')

pandas_df_rapgap = pandas_df_rapgap.query('from_tlv_gen_Q2 > 200')

pandas_df_rapgap = pandas_df_rapgap.query('e_ecal_over_trk_ratio > 0')

#-- 2023-06-23 : remove small fraction of events that have gen_hfs_etacut_e = 0

pandas_df_rapgap = pandas_df_rapgap.query('gen_hfs_etacut_e > 0')

print('\n\n Number of entries in pandas_df_rapgap:  %d ' % pandas_df_rapgap.shape[0] )
# Out:
#  Number of entries in pandas_df_rapgap:  123966

# %%
pandas_df_django = pandas_df_django.query('Empz > 0')

pandas_df_django = pandas_df_django.query('obs_event_Empz > 46 and obs_event_Empz < 62')

pandas_df_django = pandas_df_django.query('obs_hfs_pt > 0')

pandas_df_django = pandas_df_django.query('from_tlv_gen_Q2 > 200')

pandas_df_django = pandas_df_django.query('e_ecal_over_trk_ratio > 0')

#-- 2023-06-23 : remove small fraction of events that have gen_hfs_etacut_e = 0

pandas_df_django = pandas_df_django.query('gen_hfs_etacut_e > 0')

print('\n\n Number of entries in pandas_df_django:  %d ' % pandas_df_django.shape[0] )
# Out:
#  Number of entries in pandas_df_django:  113333

# %%
pandas_df_rapgap
# Out:
#         has_isr  has_fsr  tower_sum_40  n_towers_40  eta_pho_closest_to_ebeam  \
# entry
# 23            0        0     24.247692            1                 -0.182699
# 36            0        1     13.348120            1                 -1.709016
# 45            0        0     25.104801            1                 -0.021559
# 47            0        1     20.143602            1                  0.018809
# 56            1        0     32.968731            1                  0.195189
# ...         ...      ...           ...          ...                       ...
# 599961        0        1     24.405752            1                  0.283461
# 599962        0        0     26.470289            1                 -0.394084
# 599964        0        0     19.932323            1                  0.487170
# 599971        0        0     26.509193            1                  0.075173
# 599995        0        0     17.017975            1                 -0.206289
#
#         e_pho_closest_to_ebeam  phi_pho_closest_to_ebeam  obs_x[0]  obs_x[1]  \
# entry
# 23                    0.144760                  2.422777  0.015283  0.019567
# 36                    0.566964                 -0.436204  0.003809  0.002255
# 45                    1.420366                  2.370969  0.013934  0.019074
# 47                    0.729400                 -1.816074  0.007061  0.004471
# 56                    0.114277                  0.189013  0.092370  0.113946
# ...                        ...                       ...       ...       ...
# 599961                0.221700                  0.071227  0.016129  0.013962
# 599962                0.544118                 -0.737230  0.027526  0.027821
# 599964                0.373155                 -2.720732  0.006788  0.002701
# 599971                1.423583                  0.053469  0.027185  0.027381
# 599995                6.327857                 -1.405676  0.004879  0.005448
#
#         obs_x[2]  ...  rot_Empz2  gen_log_x  gen_log_y  gen_log_Q2  \
# entry             ...
# 23      0.009369  ...  43.001450  -4.329937  -1.276337    5.922210
# 36      0.004362  ...  37.739708  -5.503805  -0.571310    5.453369
# 45      0.008570  ...  42.132053  -4.499992  -1.604122    5.424370
# 47      0.008294  ...  37.633305  -4.799874  -1.136600    5.592010
# 56      0.127623  ...  38.093636  -1.782004  -2.935359    6.801494
# ...          ...  ...        ...        ...        ...         ...
# 599961  0.019490  ...  37.712376  -4.033729  -1.460758    6.033998
# 599962  0.021021  ...  41.649895  -3.487934  -0.750738    7.289812
# 599964  0.008654  ...  36.933609  -4.917424  -1.075085    5.535975
# 599971  0.023926  ...  40.258453  -3.535892  -0.898193    7.094399
# 599995  0.004675  ...  39.446136  -5.366909  -0.741646    5.419930
#
#         e_ecal_over_trk_ratio  dphi_pho_closest_to_ebeam  has_norad  \
# entry
# 23                   1.071315                   0.428013       True
# 36                   0.988650                   2.755722      False
# 45                   2.409008                   3.302941       True
# 47                   1.761387                   2.691795      False
# 56                   0.950580                   3.264253      False
# ...                       ...                        ...        ...
# 599961               2.058355                   2.947433      False
# 599962               1.331015                   2.506685       True
# 599964               1.002115                   1.711251       True
# 599971               0.959667                   4.036228       True
# 599995               4.000000                   4.350861       True
#
#         obs_ptbal  obs_pzbal  gen_dphi_etacut
# entry
# 23       0.060719  -0.101689         3.202085
# 36      -0.035760   0.033116         3.166307
# 45       0.168212  -0.079415         3.160574
# 47       0.091957   0.035842         3.144557
# 56       0.052082   0.024048         3.155321
# ...           ...        ...              ...
# 599961  -0.042688   0.033816         3.145838
# 599962   0.185912  -0.067062         3.165860
# 599964   0.037301   0.053768         3.172590
# 599971   0.184208  -0.031414         3.113834
# 599995   0.174466  -0.010603         3.159815
#
# [123966 rows x 82 columns]

# %%
pandas_df_django
# Out:
#         has_isr  has_fsr  tower_sum_40  n_towers_40  eta_pho_closest_to_ebeam  \
# entry
# 20            0        0     17.255196            1                 -1.066193
# 22            0        0     29.893789            1                  0.895007
# 27            0        0     23.783131            1                 -0.131410
# 33            1        0     24.646885            1                  1.005825
# 38            0        0     12.380091            1                 -2.888133
# ...         ...      ...           ...          ...                       ...
# 599975        0        0     17.030645            1                 -2.039463
# 599977        0        0     21.301506            1                 -0.392703
# 599982        0        0     18.964705            1                  0.681341
# 599984        0        0     26.860796            1                  0.720163
# 599990        0        0     12.163277            1                 -2.285767
#
#         e_pho_closest_to_ebeam  phi_pho_closest_to_ebeam  obs_x[0]  obs_x[1]  \
# entry
# 20                    0.240274                  1.518299  0.004745  0.002059
# 22                    0.601942                  2.087080  0.052515  0.058272
# 27                    0.446848                 -1.933851  0.011714  0.016146
# 33                    0.120665                  0.242550  0.015225  0.018389
# 38                    1.764309                 -0.540577  0.003480  0.003441
# ...                        ...                       ...       ...       ...
# 599975                0.962931                  0.955288  0.005116  0.006974
# 599977                0.557192                 -2.509399  0.014702  0.014472
# 599982                0.761786                 -0.533696  0.004506 -0.014924
# 599984                0.600201                 -0.313643  0.026154  0.026680
# 599990                0.397117                 -1.422425  0.008858  0.008359
#
#         obs_x[2]  ...  rot_Empz2  gen_log_x  gen_log_y  gen_log_Q2  \
# entry             ...
# 20      0.005654  ...  37.362167  -5.230584  -0.867193    5.430706
# 22      0.067616  ...  38.152119  -2.721840  -2.399088    6.407556
# 27      0.008042  ...  41.864983  -4.471905  -1.468582    5.587996
# 33      0.011058  ...  41.343658  -4.208622  -1.516757    5.799310
# 38      0.003494  ...  38.996613  -5.732018  -0.448362    5.348104
# ...          ...  ...        ...        ...        ...         ...
# 599975  0.004406  ...  40.486641  -5.242100  -0.795208    5.491176
# 599977  0.015101  ...  38.774117  -4.136191  -0.851233    6.541059
# 599982  0.009940  ...  32.817074  -4.494414  -1.609468    5.424601
# 599984  0.021634  ...  40.323883  -3.720333  -1.500490    6.307661
# 599990  0.009872  ...  38.317528  -4.784894  -0.219506    6.524084
#
#         e_ecal_over_trk_ratio  dphi_pho_closest_to_ebeam  has_norad  \
# entry
# 20                   0.931784                   2.221198       True
# 22                   0.984936                   2.996598       True
# 27                   1.080399                   2.321987       True
# 33                   1.080347                   1.063548      False
# 38                   0.986371                   3.510371       True
# ...                       ...                        ...        ...
# 599975               1.023899                   4.361492       True
# 599977               0.955187                   2.632432       True
# 599982               0.779859                   3.634881       True
# 599984               1.011260                   3.544816       True
# 599990               1.045483                   5.770128       True
#
#         obs_ptbal  obs_pzbal  gen_dphi_etacut
# entry
# 20       0.123451   0.042788         3.177054
# 22      -0.094159   0.022550         3.175841
# 27       0.317030  -0.072573         3.076885
# 33       0.240941  -0.059217         3.212621
# 38      -0.131654   0.000914         3.076051
# ...           ...        ...              ...
# 599975  -0.389356  -0.037260         3.088061
# 599977   0.079795   0.006615         3.131365
# 599982   0.224206   0.159233         3.131109
# 599984   0.044401  -0.033090         3.138517
# 599990   0.092832   0.018312         3.199745
#
# [113333 rows x 82 columns]

# %% [markdown]
# ## Set up machine learning stuff

# %%
X_gen_r = np.c_[
    pandas_df_rapgap['gen_e_e'].to_numpy(),
    pandas_df_rapgap['gen_e_pz'].to_numpy(),
    pandas_df_rapgap['gen_e_pt'].to_numpy(),
    pandas_df_rapgap['gen_e_eta'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_e'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_pz'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_pt'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_eta'].to_numpy(),
    pandas_df_rapgap['gen_dphi_etacut'].to_numpy(),
]

X_obs_r = np.c_[
    pandas_df_rapgap['obs_e_e'].to_numpy(),
    pandas_df_rapgap['obs_e_pz'].to_numpy(),
    pandas_df_rapgap['obs_e_pt'].to_numpy(),
    pandas_df_rapgap['obs_e_eta'].to_numpy(),
    pandas_df_rapgap['obs_hfs_e'].to_numpy(),
    pandas_df_rapgap['obs_hfs_pz'].to_numpy(),
    pandas_df_rapgap['obs_hfs_pt'].to_numpy(),
    pandas_df_rapgap['obs_hfs_eta'].to_numpy(),
    pandas_df_rapgap['obs_dphi'].to_numpy(),
]

X_r = np.c_[
    pandas_df_rapgap['gen_e_e'].to_numpy(),
    pandas_df_rapgap['gen_e_pz'].to_numpy(),
    pandas_df_rapgap['gen_e_pt'].to_numpy(),
    pandas_df_rapgap['gen_e_eta'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_e'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_pz'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_pt'].to_numpy(),
    pandas_df_rapgap['gen_hfs_etacut_eta'].to_numpy(),
    pandas_df_rapgap['gen_dphi_etacut'].to_numpy(),
    pandas_df_rapgap['obs_e_e'].to_numpy(),
    pandas_df_rapgap['obs_e_pz'].to_numpy(),
    pandas_df_rapgap['obs_e_pt'].to_numpy(),
    pandas_df_rapgap['obs_e_eta'].to_numpy(),
    pandas_df_rapgap['obs_hfs_e'].to_numpy(),
    pandas_df_rapgap['obs_hfs_pz'].to_numpy(),
    pandas_df_rapgap['obs_hfs_pt'].to_numpy(),
    pandas_df_rapgap['obs_hfs_eta'].to_numpy(),
    pandas_df_rapgap['obs_dphi'].to_numpy(),
]


w_r = np.c_[
    pandas_df_rapgap['wgt'].to_numpy(),
]

Y_r = np.c_[
    np.ones(len(pandas_df_rapgap))
]

# %%
print(" shapes:  X_gen_r = %s , X_obs_r = %s , X_r = %s,   w_r = %s , Y_r = %s" % ( str(np.shape(X_gen_r)), str(np.shape(X_obs_r)), str(np.shape(X_r)),str(np.shape(w_r)), str(np.shape(Y_r)) ) )
# Out:
#  shapes:  X_gen_r = (123966, 9) , X_obs_r = (123966, 9) , X_r = (123966, 18),   w_r = (123966, 1) , Y_r = (123966, 1)

# %%
X_gen_d = np.c_[
    pandas_df_django['gen_e_e'].to_numpy(),
    pandas_df_django['gen_e_pz'].to_numpy(),
    pandas_df_django['gen_e_pt'].to_numpy(),
    pandas_df_django['gen_e_eta'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_e'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_pz'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_pt'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_eta'].to_numpy(),
    pandas_df_django['gen_dphi_etacut'].to_numpy(),
]

X_obs_d = np.c_[
    pandas_df_django['obs_e_e'].to_numpy(),
    pandas_df_django['obs_e_pz'].to_numpy(),
    pandas_df_django['obs_e_pt'].to_numpy(),
    pandas_df_django['obs_e_eta'].to_numpy(),
    pandas_df_django['obs_hfs_e'].to_numpy(),
    pandas_df_django['obs_hfs_pz'].to_numpy(),
    pandas_df_django['obs_hfs_pt'].to_numpy(),
    pandas_df_django['obs_hfs_eta'].to_numpy(),
    pandas_df_django['obs_dphi'].to_numpy(),
]

X_d = np.c_[
    pandas_df_django['gen_e_e'].to_numpy(),
    pandas_df_django['gen_e_pz'].to_numpy(),
    pandas_df_django['gen_e_pt'].to_numpy(),
    pandas_df_django['gen_e_eta'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_e'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_pz'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_pt'].to_numpy(),
    pandas_df_django['gen_hfs_etacut_eta'].to_numpy(),
    pandas_df_django['gen_dphi_etacut'].to_numpy(),
    pandas_df_django['obs_e_e'].to_numpy(),
    pandas_df_django['obs_e_pz'].to_numpy(),
    pandas_df_django['obs_e_pt'].to_numpy(),
    pandas_df_django['obs_e_eta'].to_numpy(),
    pandas_df_django['obs_hfs_e'].to_numpy(),
    pandas_df_django['obs_hfs_pz'].to_numpy(),
    pandas_df_django['obs_hfs_pt'].to_numpy(),
    pandas_df_django['obs_hfs_eta'].to_numpy(),
    pandas_df_django['obs_dphi'].to_numpy(),
]


w_d = np.c_[
    pandas_df_django['wgt'].to_numpy(),
]

Y_d = np.c_[
    np.zeros(len(pandas_df_django))
]

# %%
print(" shapes:  X_gen_d = %s , X_obs_d = %s , X_d = %s,  w_d = %s , Y_d = %s" % ( str(np.shape(X_gen_d)), str(np.shape(X_obs_d)), str(np.shape(X_d)), str(np.shape(w_d)), str(np.shape(Y_d)) ) )
# Out:
#  shapes:  X_gen_d = (113333, 9) , X_obs_d = (113333, 9) , X_d = (113333, 18),  w_d = (113333, 1) , Y_d = (113333, 1)

# %%
X_gen = np.concatenate( [X_gen_r, X_gen_d] )
X_obs = np.concatenate( [X_obs_r, X_obs_d] )

X = np.concatenate( [X_r, X_d] )

w = np.concatenate( [w_r, w_d])

Y = np.concatenate( [Y_r, Y_d])

# %%
print(" shapes:  X_gen = %s , X_obs = %s ,  X = %s,  w = %s , Y = %s" % ( str(np.shape(X_gen)),  str(np.shape(X_obs)),   str(np.shape(X)),  str(np.shape(w)), str(np.shape(Y)) ) )
# Out:
#  shapes:  X_gen = (237299, 9) , X_obs = (237299, 9) ,  X = (237299, 18),  w = (237299, 1) , Y = (237299, 1)

# %%
scaler_file = "%s/input-scaler.pkl" % output_dir

if run_training :
    print("Creating new scaler.")
    scalerX = StandardScaler()
    scalerX.fit(X)
else :
    print("Reading scaler from file: %s" % scaler_file )
    scalerX = load( open(scaler_file, 'rb') )
    
Xs = scalerX.transform(X)


if run_training :
    print("Saving scaler to %s" % scaler_file)
    dump( scalerX, open(scaler_file, 'wb'))
# Out:
# Creating new scaler.
# Saving scaler to training-bce-mse-version1c-training-output/input-scaler.pkl

# %%
X_train, X_test, Y_train, Y_test, w_train, w_test = train_test_split( Xs, Y, w, test_size=0.5 )

# %%
print("\n shapes:  X_gen_train = %s , X_obs_train = %s" % ( str(np.shape(X_train)), str(np.shape(X_train))))
# Out:
#  shapes:  X_gen_train = (118649, 18) , X_obs_train = (118649, 18)

# %%
Xs_d = scalerX.transform( X_d )

Xs_r = scalerX.transform( X_r )

# %%
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def custom_loss_simple(y_true, y_pred):
    particle_level = y_pred
    loss = bce(y_true,particle_level)  
    #tf.print("custom_loss_simple : loss ", loss)
    #tf.print("custom_loss_simple :  y_true ", y_true, " y_pred ", y_pred )
    return loss

# %% [markdown]
# ## First, look at a simple particle-level classifier

# %%
n = 9  # Number of features in input.

inputs = Input(shape=(2*n,))


classifier_nn = Sequential()
classifier_nn.add( Dense( 50, activation="relu", input_dim=n) )
classifier_nn.add( Dense( 50, activation="relu"))
classifier_nn.add( Dense( 1, activation="sigmoid"))

particle_inputs_model = classifier_nn( inputs[:,0:n] )

output = particle_inputs_model


mymodel = Model( inputs=[inputs], outputs=[output])

opt_adam = tf.keras.optimizers.Adam(learning_rate=learning_rate_setval, amsgrad=False )

#mymodel.compile( loss='binary_crossentropy', optimizer=opt_adam, metrics=['accuracy'] )

mymodel.compile( loss=custom_loss_simple, optimizer=opt_adam, metrics=['accuracy'] )
# Out:
# 2023-08-13 11:11:01.731023: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:11:01.731279: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:11:01.731451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:11:01.731663: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:11:01.731838: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-08-13 11:11:01.731977: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21980 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:41:00.0, compute capability: 8.6

# %%
training_hist = mymodel.fit( X_train, Y_train, validation_data=(X_test, Y_test), 
            epochs=150, 
            batch_size=batch_size_setval,
           verbose=1)
# Out:
# Epoch 1/150
# /usr/lib/python3/dist-packages/keras/backend.py:5676: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 2023-08-13 11:11:02.968223: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-13 11:11:02.970849: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f81a0027830 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-13 11:11:02.970882: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-08-13 11:11:02.977349: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-13 11:11:03.085948: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 29/29 [==============================] - 2s 8ms/step - loss: 0.7117 - accuracy: 0.5109 - val_loss: 0.6837 - val_accuracy: 0.5667
# Epoch 2/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6769 - accuracy: 0.5828 - val_loss: 0.6721 - val_accuracy: 0.5932
# Epoch 3/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6682 - accuracy: 0.6022 - val_loss: 0.6665 - val_accuracy: 0.6078
# Epoch 4/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6636 - accuracy: 0.6119 - val_loss: 0.6639 - val_accuracy: 0.6119
# Epoch 5/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6614 - accuracy: 0.6152 - val_loss: 0.6622 - val_accuracy: 0.6153
# Epoch 6/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6598 - accuracy: 0.6168 - val_loss: 0.6609 - val_accuracy: 0.6167
# Epoch 7/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6586 - accuracy: 0.6182 - val_loss: 0.6600 - val_accuracy: 0.6169
# Epoch 8/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6576 - accuracy: 0.6188 - val_loss: 0.6590 - val_accuracy: 0.6180
# Epoch 9/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6568 - accuracy: 0.6193 - val_loss: 0.6581 - val_accuracy: 0.6190
# Epoch 10/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6559 - accuracy: 0.6201 - val_loss: 0.6576 - val_accuracy: 0.6185
# Epoch 11/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6552 - accuracy: 0.6204 - val_loss: 0.6570 - val_accuracy: 0.6190
# Epoch 12/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6544 - accuracy: 0.6215 - val_loss: 0.6562 - val_accuracy: 0.6212
# Epoch 13/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6537 - accuracy: 0.6220 - val_loss: 0.6559 - val_accuracy: 0.6209
# Epoch 14/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6532 - accuracy: 0.6221 - val_loss: 0.6550 - val_accuracy: 0.6214
# Epoch 15/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6525 - accuracy: 0.6221 - val_loss: 0.6545 - val_accuracy: 0.6212
# Epoch 16/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6518 - accuracy: 0.6230 - val_loss: 0.6543 - val_accuracy: 0.6222
# Epoch 17/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6516 - accuracy: 0.6232 - val_loss: 0.6534 - val_accuracy: 0.6227
# Epoch 18/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6512 - accuracy: 0.6227 - val_loss: 0.6532 - val_accuracy: 0.6223
# Epoch 19/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6505 - accuracy: 0.6232 - val_loss: 0.6525 - val_accuracy: 0.6237
# Epoch 20/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6501 - accuracy: 0.6239 - val_loss: 0.6521 - val_accuracy: 0.6240
# Epoch 21/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6494 - accuracy: 0.6246 - val_loss: 0.6519 - val_accuracy: 0.6233
# Epoch 22/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6494 - accuracy: 0.6242 - val_loss: 0.6514 - val_accuracy: 0.6246
# Epoch 23/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6488 - accuracy: 0.6241 - val_loss: 0.6515 - val_accuracy: 0.6240
# Epoch 24/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6486 - accuracy: 0.6252 - val_loss: 0.6507 - val_accuracy: 0.6236
# Epoch 25/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.6259 - val_loss: 0.6503 - val_accuracy: 0.6247
# Epoch 26/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6479 - accuracy: 0.6254 - val_loss: 0.6502 - val_accuracy: 0.6245
# Epoch 27/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6477 - accuracy: 0.6262 - val_loss: 0.6500 - val_accuracy: 0.6243
# Epoch 28/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6472 - accuracy: 0.6258 - val_loss: 0.6497 - val_accuracy: 0.6263
# Epoch 29/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6469 - accuracy: 0.6265 - val_loss: 0.6495 - val_accuracy: 0.6261
# Epoch 30/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6467 - accuracy: 0.6264 - val_loss: 0.6493 - val_accuracy: 0.6257
# Epoch 31/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.6275 - val_loss: 0.6488 - val_accuracy: 0.6261
# Epoch 32/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6462 - accuracy: 0.6264 - val_loss: 0.6490 - val_accuracy: 0.6264
# Epoch 33/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6459 - accuracy: 0.6280 - val_loss: 0.6485 - val_accuracy: 0.6267
# Epoch 34/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6454 - accuracy: 0.6287 - val_loss: 0.6481 - val_accuracy: 0.6277
# Epoch 35/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6450 - accuracy: 0.6291 - val_loss: 0.6477 - val_accuracy: 0.6280
# Epoch 36/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6446 - accuracy: 0.6295 - val_loss: 0.6470 - val_accuracy: 0.6283
# Epoch 37/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6441 - accuracy: 0.6304 - val_loss: 0.6467 - val_accuracy: 0.6291
# Epoch 38/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6434 - accuracy: 0.6312 - val_loss: 0.6460 - val_accuracy: 0.6301
# Epoch 39/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6429 - accuracy: 0.6317 - val_loss: 0.6463 - val_accuracy: 0.6305
# Epoch 40/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6422 - accuracy: 0.6332 - val_loss: 0.6449 - val_accuracy: 0.6317
# Epoch 41/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6415 - accuracy: 0.6336 - val_loss: 0.6440 - val_accuracy: 0.6331
# Epoch 42/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6409 - accuracy: 0.6357 - val_loss: 0.6439 - val_accuracy: 0.6335
# Epoch 43/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6404 - accuracy: 0.6367 - val_loss: 0.6440 - val_accuracy: 0.6348
# Epoch 44/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6399 - accuracy: 0.6375 - val_loss: 0.6428 - val_accuracy: 0.6351
# Epoch 45/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6392 - accuracy: 0.6379 - val_loss: 0.6419 - val_accuracy: 0.6369
# Epoch 46/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6391 - accuracy: 0.6386 - val_loss: 0.6415 - val_accuracy: 0.6373
# Epoch 47/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.6405 - val_loss: 0.6405 - val_accuracy: 0.6393
# Epoch 48/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6369 - accuracy: 0.6423 - val_loss: 0.6402 - val_accuracy: 0.6399
# Epoch 49/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6365 - accuracy: 0.6434 - val_loss: 0.6394 - val_accuracy: 0.6411
# Epoch 50/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6358 - accuracy: 0.6439 - val_loss: 0.6386 - val_accuracy: 0.6429
# Epoch 51/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6354 - accuracy: 0.6455 - val_loss: 0.6389 - val_accuracy: 0.6425
# Epoch 52/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6347 - accuracy: 0.6466 - val_loss: 0.6380 - val_accuracy: 0.6437
# Epoch 53/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6341 - accuracy: 0.6482 - val_loss: 0.6375 - val_accuracy: 0.6442
# Epoch 54/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6336 - accuracy: 0.6485 - val_loss: 0.6378 - val_accuracy: 0.6437
# Epoch 55/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6332 - accuracy: 0.6489 - val_loss: 0.6363 - val_accuracy: 0.6464
# Epoch 56/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6499 - val_loss: 0.6360 - val_accuracy: 0.6464
# Epoch 57/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6321 - accuracy: 0.6504 - val_loss: 0.6354 - val_accuracy: 0.6472
# Epoch 58/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6316 - accuracy: 0.6515 - val_loss: 0.6349 - val_accuracy: 0.6471
# Epoch 59/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6313 - accuracy: 0.6521 - val_loss: 0.6346 - val_accuracy: 0.6485
# Epoch 60/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6306 - accuracy: 0.6515 - val_loss: 0.6342 - val_accuracy: 0.6494
# Epoch 61/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6304 - accuracy: 0.6526 - val_loss: 0.6345 - val_accuracy: 0.6495
# Epoch 62/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6297 - accuracy: 0.6535 - val_loss: 0.6335 - val_accuracy: 0.6497
# Epoch 63/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6293 - accuracy: 0.6534 - val_loss: 0.6332 - val_accuracy: 0.6504
# Epoch 64/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6292 - accuracy: 0.6541 - val_loss: 0.6332 - val_accuracy: 0.6504
# Epoch 65/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6289 - accuracy: 0.6542 - val_loss: 0.6335 - val_accuracy: 0.6494
# Epoch 66/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6285 - accuracy: 0.6545 - val_loss: 0.6320 - val_accuracy: 0.6515
# Epoch 67/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6278 - accuracy: 0.6554 - val_loss: 0.6321 - val_accuracy: 0.6509
# Epoch 68/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6281 - accuracy: 0.6552 - val_loss: 0.6317 - val_accuracy: 0.6510
# Epoch 69/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6274 - accuracy: 0.6563 - val_loss: 0.6312 - val_accuracy: 0.6525
# Epoch 70/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6271 - accuracy: 0.6570 - val_loss: 0.6312 - val_accuracy: 0.6517
# Epoch 71/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6268 - accuracy: 0.6572 - val_loss: 0.6306 - val_accuracy: 0.6524
# Epoch 72/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6267 - accuracy: 0.6566 - val_loss: 0.6304 - val_accuracy: 0.6527
# Epoch 73/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.6575 - val_loss: 0.6302 - val_accuracy: 0.6531
# Epoch 74/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6263 - accuracy: 0.6573 - val_loss: 0.6303 - val_accuracy: 0.6537
# Epoch 75/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6262 - accuracy: 0.6578 - val_loss: 0.6311 - val_accuracy: 0.6527
# Epoch 76/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6257 - accuracy: 0.6574 - val_loss: 0.6306 - val_accuracy: 0.6534
# Epoch 77/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6259 - accuracy: 0.6569 - val_loss: 0.6296 - val_accuracy: 0.6540
# Epoch 78/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6252 - accuracy: 0.6582 - val_loss: 0.6299 - val_accuracy: 0.6542
# Epoch 79/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6252 - accuracy: 0.6585 - val_loss: 0.6296 - val_accuracy: 0.6532
# Epoch 80/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6251 - accuracy: 0.6581 - val_loss: 0.6294 - val_accuracy: 0.6543
# Epoch 81/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6249 - accuracy: 0.6587 - val_loss: 0.6300 - val_accuracy: 0.6526
# Epoch 82/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6250 - accuracy: 0.6584 - val_loss: 0.6301 - val_accuracy: 0.6529
# Epoch 83/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6251 - accuracy: 0.6577 - val_loss: 0.6297 - val_accuracy: 0.6547
# Epoch 84/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6244 - accuracy: 0.6587 - val_loss: 0.6301 - val_accuracy: 0.6532
# Epoch 85/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6246 - accuracy: 0.6587 - val_loss: 0.6290 - val_accuracy: 0.6534
# Epoch 86/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6242 - accuracy: 0.6589 - val_loss: 0.6290 - val_accuracy: 0.6536
# Epoch 87/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6241 - accuracy: 0.6589 - val_loss: 0.6285 - val_accuracy: 0.6540
# Epoch 88/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6238 - accuracy: 0.6590 - val_loss: 0.6287 - val_accuracy: 0.6535
# Epoch 89/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6239 - accuracy: 0.6586 - val_loss: 0.6288 - val_accuracy: 0.6542
# Epoch 90/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6241 - accuracy: 0.6594 - val_loss: 0.6290 - val_accuracy: 0.6544
# Epoch 91/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6240 - accuracy: 0.6592 - val_loss: 0.6287 - val_accuracy: 0.6556
# Epoch 92/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6235 - accuracy: 0.6589 - val_loss: 0.6286 - val_accuracy: 0.6546
# Epoch 93/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6239 - accuracy: 0.6587 - val_loss: 0.6294 - val_accuracy: 0.6526
# Epoch 94/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6239 - accuracy: 0.6584 - val_loss: 0.6283 - val_accuracy: 0.6550
# Epoch 95/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.6603 - val_loss: 0.6284 - val_accuracy: 0.6544
# Epoch 96/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6232 - accuracy: 0.6595 - val_loss: 0.6281 - val_accuracy: 0.6560
# Epoch 97/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6229 - accuracy: 0.6597 - val_loss: 0.6285 - val_accuracy: 0.6546
# Epoch 98/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6230 - accuracy: 0.6607 - val_loss: 0.6279 - val_accuracy: 0.6544
# Epoch 99/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6229 - accuracy: 0.6597 - val_loss: 0.6280 - val_accuracy: 0.6552
# Epoch 100/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6229 - accuracy: 0.6601 - val_loss: 0.6290 - val_accuracy: 0.6540
# Epoch 101/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6228 - accuracy: 0.6602 - val_loss: 0.6282 - val_accuracy: 0.6556
# Epoch 102/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6226 - accuracy: 0.6600 - val_loss: 0.6280 - val_accuracy: 0.6554
# Epoch 103/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6225 - accuracy: 0.6601 - val_loss: 0.6287 - val_accuracy: 0.6551
# Epoch 104/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6224 - accuracy: 0.6609 - val_loss: 0.6275 - val_accuracy: 0.6553
# Epoch 105/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6224 - accuracy: 0.6602 - val_loss: 0.6278 - val_accuracy: 0.6545
# Epoch 106/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6222 - accuracy: 0.6613 - val_loss: 0.6273 - val_accuracy: 0.6552
# Epoch 107/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6220 - accuracy: 0.6608 - val_loss: 0.6275 - val_accuracy: 0.6556
# Epoch 108/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6225 - accuracy: 0.6601 - val_loss: 0.6279 - val_accuracy: 0.6555
# Epoch 109/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6219 - accuracy: 0.6604 - val_loss: 0.6277 - val_accuracy: 0.6557
# Epoch 110/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6221 - accuracy: 0.6602 - val_loss: 0.6282 - val_accuracy: 0.6554
# Epoch 111/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6219 - accuracy: 0.6613 - val_loss: 0.6275 - val_accuracy: 0.6554
# Epoch 112/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6218 - accuracy: 0.6604 - val_loss: 0.6275 - val_accuracy: 0.6545
# Epoch 113/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6216 - accuracy: 0.6616 - val_loss: 0.6273 - val_accuracy: 0.6547
# Epoch 114/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6218 - accuracy: 0.6608 - val_loss: 0.6274 - val_accuracy: 0.6561
# Epoch 115/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6219 - accuracy: 0.6605 - val_loss: 0.6283 - val_accuracy: 0.6547
# Epoch 116/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6218 - accuracy: 0.6606 - val_loss: 0.6275 - val_accuracy: 0.6558
# Epoch 117/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6213 - accuracy: 0.6616 - val_loss: 0.6273 - val_accuracy: 0.6560
# Epoch 118/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6213 - accuracy: 0.6604 - val_loss: 0.6272 - val_accuracy: 0.6552
# Epoch 119/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6215 - accuracy: 0.6607 - val_loss: 0.6272 - val_accuracy: 0.6557
# Epoch 120/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6214 - accuracy: 0.6615 - val_loss: 0.6269 - val_accuracy: 0.6551
# Epoch 121/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6214 - accuracy: 0.6609 - val_loss: 0.6274 - val_accuracy: 0.6557
# Epoch 122/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6213 - accuracy: 0.6606 - val_loss: 0.6279 - val_accuracy: 0.6546
# Epoch 123/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6211 - accuracy: 0.6613 - val_loss: 0.6272 - val_accuracy: 0.6564
# Epoch 124/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6211 - accuracy: 0.6611 - val_loss: 0.6280 - val_accuracy: 0.6551
# Epoch 125/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6214 - accuracy: 0.6610 - val_loss: 0.6274 - val_accuracy: 0.6553
# Epoch 126/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6211 - accuracy: 0.6606 - val_loss: 0.6269 - val_accuracy: 0.6551
# Epoch 127/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.6606 - val_loss: 0.6274 - val_accuracy: 0.6560
# Epoch 128/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.6609 - val_loss: 0.6273 - val_accuracy: 0.6548
# Epoch 129/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6210 - accuracy: 0.6618 - val_loss: 0.6269 - val_accuracy: 0.6558
# Epoch 130/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.6615 - val_loss: 0.6269 - val_accuracy: 0.6562
# Epoch 131/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6206 - accuracy: 0.6621 - val_loss: 0.6272 - val_accuracy: 0.6557
# Epoch 132/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6207 - accuracy: 0.6613 - val_loss: 0.6274 - val_accuracy: 0.6557
# Epoch 133/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6206 - accuracy: 0.6613 - val_loss: 0.6272 - val_accuracy: 0.6557
# Epoch 134/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6206 - accuracy: 0.6613 - val_loss: 0.6268 - val_accuracy: 0.6560
# Epoch 135/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6206 - accuracy: 0.6617 - val_loss: 0.6269 - val_accuracy: 0.6554
# Epoch 136/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6205 - accuracy: 0.6615 - val_loss: 0.6266 - val_accuracy: 0.6558
# Epoch 137/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6204 - accuracy: 0.6617 - val_loss: 0.6270 - val_accuracy: 0.6558
# Epoch 138/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6212 - accuracy: 0.6615 - val_loss: 0.6275 - val_accuracy: 0.6555
# Epoch 139/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6206 - accuracy: 0.6619 - val_loss: 0.6266 - val_accuracy: 0.6557
# Epoch 140/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6206 - accuracy: 0.6607 - val_loss: 0.6270 - val_accuracy: 0.6554
# Epoch 141/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6203 - accuracy: 0.6611 - val_loss: 0.6267 - val_accuracy: 0.6557
# Epoch 142/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6204 - accuracy: 0.6617 - val_loss: 0.6271 - val_accuracy: 0.6564
# Epoch 143/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6201 - accuracy: 0.6626 - val_loss: 0.6268 - val_accuracy: 0.6560
# Epoch 144/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6199 - accuracy: 0.6621 - val_loss: 0.6267 - val_accuracy: 0.6554
# Epoch 145/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6201 - accuracy: 0.6616 - val_loss: 0.6265 - val_accuracy: 0.6564
# Epoch 146/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6200 - accuracy: 0.6616 - val_loss: 0.6272 - val_accuracy: 0.6564
# Epoch 147/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6200 - accuracy: 0.6617 - val_loss: 0.6268 - val_accuracy: 0.6564
# Epoch 148/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6202 - accuracy: 0.6615 - val_loss: 0.6271 - val_accuracy: 0.6555
# Epoch 149/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6201 - accuracy: 0.6616 - val_loss: 0.6265 - val_accuracy: 0.6560
# Epoch 150/150
# 29/29 [==============================] - 0s 3ms/step - loss: 0.6198 - accuracy: 0.6622 - val_loss: 0.6267 - val_accuracy: 0.6556

# %%
plt.plot( training_hist.history['loss'] )
plt.plot( training_hist.history['val_loss'] )

# %%
mymodel.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 18)]              0
#
#  tf.__operators__.getitem (S  (None, 9)                0
#  licingOpLambda)
#
#  sequential (Sequential)     (None, 1)                 3101
#
# =================================================================
# Total params: 3,101
# Trainable params: 3,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds = mymodel.predict( X_test, batch_size=1024 )
# Out:
# 116/116 [==============================] - 0s 540us/step

# %%
fig,ax = plt.subplots(1,1,figsize=(9,7))

ax.hist( preds[Y_test==0], density=True, bins=80)
ax.hist( preds[Y_test==1], density=True, bins=80, alpha=0.7)


plt.show()

# %%
mymodel.compute_loss()

# %%
print( mymodel.compute_loss())
# Out:
# None

# %%
mymodel.evaluate( X_test, Y_test )
# Out:
# 3708/3708 [==============================] - 4s 963us/step - loss: 0.6267 - accuracy: 0.6556
# [0.6267065405845642, 0.6556004881858826]

# %% [markdown]
# ## Set up model

# %%
hp_mse_scale = 1.0

# %%
bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def custom_loss(y_true, y_pred):
    particle_level = y_pred[:,0]
    detector_level = y_pred[:,1]
    loss = bce(y_true,particle_level) 
    #tf.print( "custom_loss : loss ", loss)
    #tf.print( "custom_loss : y_true ", y_true, " y_pred ", y_pred )
    #loss = bce(y_true,detector_level) 
    #loss = bce(y_true,particle_level)  + hp_mse_scale * tf.reduce_mean(tf.square(particle_level - detector_level)) 
    return loss

# %%
n = 9  # Number of features in input.

inputs = Input(shape=(2*n,))

classifier_nn = Sequential()
classifier_nn.add( Dense( 50, activation="relu", input_dim=n) )
classifier_nn.add( Dense( 50, activation="relu"))
classifier_nn.add( Dense( 1, activation="sigmoid"))

particle_inputs_model2 = classifier_nn( inputs[:,0:n] )
detector_inputs_model2 = classifier_nn( inputs[:,n:] )

output2 = tf.stack( [particle_inputs_model2, detector_inputs_model2], axis=1)


mymodel2 = Model( inputs=[inputs], outputs=[output2])


opt_adam = tf.keras.optimizers.Adam(learning_rate=learning_rate_setval, amsgrad=False )

mymodel2.compile( loss=custom_loss, optimizer=opt_adam, metrics=['accuracy'] )

# %%
training_hist2 = mymodel2.fit( X_train, Y_train, validation_data=(X_test, Y_test), 
            epochs=150, 
            batch_size=batch_size_setval,
           verbose=1)
# Out:
# Epoch 1/150
# 29/29 [==============================] - 1s 9ms/step - loss: 0.6974 - accuracy: 0.4760 - val_loss: 0.6898 - val_accuracy: 0.4780
# Epoch 2/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6870 - accuracy: 0.4772 - val_loss: 0.6860 - val_accuracy: 0.4780
# Epoch 3/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6841 - accuracy: 0.4773 - val_loss: 0.6838 - val_accuracy: 0.4783
# Epoch 4/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6819 - accuracy: 0.4863 - val_loss: 0.6819 - val_accuracy: 0.5017
# Epoch 5/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.5076 - val_loss: 0.6802 - val_accuracy: 0.5143
# Epoch 6/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6785 - accuracy: 0.5204 - val_loss: 0.6788 - val_accuracy: 0.5222
# Epoch 7/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6772 - accuracy: 0.5293 - val_loss: 0.6776 - val_accuracy: 0.5245
# Epoch 8/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6762 - accuracy: 0.5324 - val_loss: 0.6768 - val_accuracy: 0.5365
# Epoch 9/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6755 - accuracy: 0.5393 - val_loss: 0.6761 - val_accuracy: 0.5392
# Epoch 10/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6750 - accuracy: 0.5406 - val_loss: 0.6756 - val_accuracy: 0.5433
# Epoch 11/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6746 - accuracy: 0.5459 - val_loss: 0.6753 - val_accuracy: 0.5383
# Epoch 12/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6742 - accuracy: 0.5461 - val_loss: 0.6748 - val_accuracy: 0.5449
# Epoch 13/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6738 - accuracy: 0.5481 - val_loss: 0.6744 - val_accuracy: 0.5469
# Epoch 14/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6733 - accuracy: 0.5487 - val_loss: 0.6740 - val_accuracy: 0.5534
# Epoch 15/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6731 - accuracy: 0.5513 - val_loss: 0.6740 - val_accuracy: 0.5495
# Epoch 16/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6727 - accuracy: 0.5524 - val_loss: 0.6736 - val_accuracy: 0.5548
# Epoch 17/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6725 - accuracy: 0.5538 - val_loss: 0.6734 - val_accuracy: 0.5537
# Epoch 18/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6723 - accuracy: 0.5544 - val_loss: 0.6734 - val_accuracy: 0.5540
# Epoch 19/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6722 - accuracy: 0.5551 - val_loss: 0.6733 - val_accuracy: 0.5484
# Epoch 20/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6721 - accuracy: 0.5552 - val_loss: 0.6734 - val_accuracy: 0.5590
# Epoch 21/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6722 - accuracy: 0.5545 - val_loss: 0.6732 - val_accuracy: 0.5527
# Epoch 22/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6719 - accuracy: 0.5554 - val_loss: 0.6733 - val_accuracy: 0.5622
# Epoch 23/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6718 - accuracy: 0.5560 - val_loss: 0.6728 - val_accuracy: 0.5561
# Epoch 24/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6716 - accuracy: 0.5571 - val_loss: 0.6727 - val_accuracy: 0.5547
# Epoch 25/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6715 - accuracy: 0.5563 - val_loss: 0.6727 - val_accuracy: 0.5501
# Epoch 26/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6714 - accuracy: 0.5575 - val_loss: 0.6725 - val_accuracy: 0.5575
# Epoch 27/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6713 - accuracy: 0.5580 - val_loss: 0.6725 - val_accuracy: 0.5566
# Epoch 28/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6712 - accuracy: 0.5566 - val_loss: 0.6724 - val_accuracy: 0.5581
# Epoch 29/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6710 - accuracy: 0.5576 - val_loss: 0.6723 - val_accuracy: 0.5607
# Epoch 30/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6710 - accuracy: 0.5568 - val_loss: 0.6722 - val_accuracy: 0.5599
# Epoch 31/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6709 - accuracy: 0.5582 - val_loss: 0.6721 - val_accuracy: 0.5590
# Epoch 32/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6708 - accuracy: 0.5583 - val_loss: 0.6720 - val_accuracy: 0.5568
# Epoch 33/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6706 - accuracy: 0.5580 - val_loss: 0.6719 - val_accuracy: 0.5538
# Epoch 34/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6706 - accuracy: 0.5579 - val_loss: 0.6719 - val_accuracy: 0.5610
# Epoch 35/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6705 - accuracy: 0.5584 - val_loss: 0.6718 - val_accuracy: 0.5537
# Epoch 36/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6705 - accuracy: 0.5570 - val_loss: 0.6721 - val_accuracy: 0.5554
# Epoch 37/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6703 - accuracy: 0.5590 - val_loss: 0.6719 - val_accuracy: 0.5675
# Epoch 38/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6701 - accuracy: 0.5593 - val_loss: 0.6715 - val_accuracy: 0.5558
# Epoch 39/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6699 - accuracy: 0.5586 - val_loss: 0.6713 - val_accuracy: 0.5601
# Epoch 40/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.5603 - val_loss: 0.6712 - val_accuracy: 0.5577
# Epoch 41/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6696 - accuracy: 0.5599 - val_loss: 0.6711 - val_accuracy: 0.5567
# Epoch 42/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6695 - accuracy: 0.5600 - val_loss: 0.6710 - val_accuracy: 0.5586
# Epoch 43/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6695 - accuracy: 0.5595 - val_loss: 0.6711 - val_accuracy: 0.5613
# Epoch 44/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6693 - accuracy: 0.5595 - val_loss: 0.6706 - val_accuracy: 0.5603
# Epoch 45/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6691 - accuracy: 0.5612 - val_loss: 0.6712 - val_accuracy: 0.5459
# Epoch 46/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6691 - accuracy: 0.5584 - val_loss: 0.6706 - val_accuracy: 0.5621
# Epoch 47/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6690 - accuracy: 0.5605 - val_loss: 0.6704 - val_accuracy: 0.5617
# Epoch 48/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6687 - accuracy: 0.5598 - val_loss: 0.6703 - val_accuracy: 0.5622
# Epoch 49/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6684 - accuracy: 0.5604 - val_loss: 0.6700 - val_accuracy: 0.5615
# Epoch 50/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6682 - accuracy: 0.5616 - val_loss: 0.6699 - val_accuracy: 0.5629
# Epoch 51/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6680 - accuracy: 0.5610 - val_loss: 0.6696 - val_accuracy: 0.5579
# Epoch 52/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6679 - accuracy: 0.5608 - val_loss: 0.6695 - val_accuracy: 0.5536
# Epoch 53/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6676 - accuracy: 0.5616 - val_loss: 0.6695 - val_accuracy: 0.5670
# Epoch 54/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6674 - accuracy: 0.5624 - val_loss: 0.6690 - val_accuracy: 0.5614
# Epoch 55/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6672 - accuracy: 0.5617 - val_loss: 0.6689 - val_accuracy: 0.5570
# Epoch 56/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6668 - accuracy: 0.5628 - val_loss: 0.6685 - val_accuracy: 0.5568
# Epoch 57/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6666 - accuracy: 0.5621 - val_loss: 0.6684 - val_accuracy: 0.5605
# Epoch 58/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6663 - accuracy: 0.5630 - val_loss: 0.6680 - val_accuracy: 0.5581
# Epoch 59/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6660 - accuracy: 0.5631 - val_loss: 0.6676 - val_accuracy: 0.5591
# Epoch 60/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6657 - accuracy: 0.5629 - val_loss: 0.6676 - val_accuracy: 0.5624
# Epoch 61/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6655 - accuracy: 0.5627 - val_loss: 0.6675 - val_accuracy: 0.5596
# Epoch 62/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6654 - accuracy: 0.5616 - val_loss: 0.6671 - val_accuracy: 0.5588
# Epoch 63/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6650 - accuracy: 0.5643 - val_loss: 0.6669 - val_accuracy: 0.5591
# Epoch 64/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6649 - accuracy: 0.5619 - val_loss: 0.6664 - val_accuracy: 0.5637
# Epoch 65/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6644 - accuracy: 0.5635 - val_loss: 0.6662 - val_accuracy: 0.5619
# Epoch 66/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6642 - accuracy: 0.5632 - val_loss: 0.6657 - val_accuracy: 0.5627
# Epoch 67/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6639 - accuracy: 0.5637 - val_loss: 0.6656 - val_accuracy: 0.5566
# Epoch 68/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6637 - accuracy: 0.5638 - val_loss: 0.6655 - val_accuracy: 0.5658
# Epoch 69/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6634 - accuracy: 0.5642 - val_loss: 0.6653 - val_accuracy: 0.5570
# Epoch 70/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6633 - accuracy: 0.5634 - val_loss: 0.6649 - val_accuracy: 0.5631
# Epoch 71/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6631 - accuracy: 0.5632 - val_loss: 0.6654 - val_accuracy: 0.5622
# Epoch 72/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6630 - accuracy: 0.5641 - val_loss: 0.6649 - val_accuracy: 0.5634
# Epoch 73/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6629 - accuracy: 0.5646 - val_loss: 0.6647 - val_accuracy: 0.5575
# Epoch 74/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6625 - accuracy: 0.5643 - val_loss: 0.6643 - val_accuracy: 0.5583
# Epoch 75/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.5642 - val_loss: 0.6643 - val_accuracy: 0.5575
# Epoch 76/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.5650 - val_loss: 0.6640 - val_accuracy: 0.5592
# Epoch 77/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.5637 - val_loss: 0.6639 - val_accuracy: 0.5589
# Epoch 78/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6619 - accuracy: 0.5652 - val_loss: 0.6638 - val_accuracy: 0.5599
# Epoch 79/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6618 - accuracy: 0.5644 - val_loss: 0.6638 - val_accuracy: 0.5689
# Epoch 80/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6615 - accuracy: 0.5652 - val_loss: 0.6639 - val_accuracy: 0.5675
# Epoch 81/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6616 - accuracy: 0.5650 - val_loss: 0.6638 - val_accuracy: 0.5606
# Epoch 82/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6614 - accuracy: 0.5641 - val_loss: 0.6641 - val_accuracy: 0.5739
# Epoch 83/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6613 - accuracy: 0.5657 - val_loss: 0.6634 - val_accuracy: 0.5646
# Epoch 84/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6611 - accuracy: 0.5651 - val_loss: 0.6633 - val_accuracy: 0.5664
# Epoch 85/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6611 - accuracy: 0.5651 - val_loss: 0.6633 - val_accuracy: 0.5646
# Epoch 86/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6610 - accuracy: 0.5640 - val_loss: 0.6633 - val_accuracy: 0.5646
# Epoch 87/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6608 - accuracy: 0.5664 - val_loss: 0.6630 - val_accuracy: 0.5621
# Epoch 88/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6606 - accuracy: 0.5664 - val_loss: 0.6631 - val_accuracy: 0.5589
# Epoch 89/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6607 - accuracy: 0.5642 - val_loss: 0.6631 - val_accuracy: 0.5673
# Epoch 90/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6606 - accuracy: 0.5667 - val_loss: 0.6628 - val_accuracy: 0.5569
# Epoch 91/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6605 - accuracy: 0.5652 - val_loss: 0.6627 - val_accuracy: 0.5695
# Epoch 92/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6604 - accuracy: 0.5655 - val_loss: 0.6630 - val_accuracy: 0.5591
# Epoch 93/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6604 - accuracy: 0.5661 - val_loss: 0.6626 - val_accuracy: 0.5633
# Epoch 94/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6603 - accuracy: 0.5660 - val_loss: 0.6624 - val_accuracy: 0.5678
# Epoch 95/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6602 - accuracy: 0.5660 - val_loss: 0.6625 - val_accuracy: 0.5617
# Epoch 96/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6602 - accuracy: 0.5658 - val_loss: 0.6625 - val_accuracy: 0.5709
# Epoch 97/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6601 - accuracy: 0.5654 - val_loss: 0.6622 - val_accuracy: 0.5651
# Epoch 98/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.5664 - val_loss: 0.6620 - val_accuracy: 0.5640
# Epoch 99/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.5660 - val_loss: 0.6624 - val_accuracy: 0.5648
# Epoch 100/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.5670 - val_loss: 0.6620 - val_accuracy: 0.5640
# Epoch 101/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.5660 - val_loss: 0.6622 - val_accuracy: 0.5606
# Epoch 102/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.5659 - val_loss: 0.6619 - val_accuracy: 0.5655
# Epoch 103/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.5670 - val_loss: 0.6620 - val_accuracy: 0.5658
# Epoch 104/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6598 - accuracy: 0.5668 - val_loss: 0.6623 - val_accuracy: 0.5669
# Epoch 105/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6598 - accuracy: 0.5664 - val_loss: 0.6623 - val_accuracy: 0.5640
# Epoch 106/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.5665 - val_loss: 0.6627 - val_accuracy: 0.5656
# Epoch 107/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6599 - accuracy: 0.5665 - val_loss: 0.6621 - val_accuracy: 0.5674
# Epoch 108/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6596 - accuracy: 0.5666 - val_loss: 0.6622 - val_accuracy: 0.5681
# Epoch 109/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6598 - accuracy: 0.5667 - val_loss: 0.6619 - val_accuracy: 0.5625
# Epoch 110/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.5672 - val_loss: 0.6618 - val_accuracy: 0.5660
# Epoch 111/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.5661 - val_loss: 0.6620 - val_accuracy: 0.5610
# Epoch 112/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6598 - accuracy: 0.5658 - val_loss: 0.6623 - val_accuracy: 0.5669
# Epoch 113/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6597 - accuracy: 0.5675 - val_loss: 0.6621 - val_accuracy: 0.5647
# Epoch 114/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6595 - accuracy: 0.5661 - val_loss: 0.6621 - val_accuracy: 0.5596
# Epoch 115/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6596 - accuracy: 0.5668 - val_loss: 0.6621 - val_accuracy: 0.5638
# Epoch 116/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.5667 - val_loss: 0.6619 - val_accuracy: 0.5706
# Epoch 117/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6595 - accuracy: 0.5672 - val_loss: 0.6617 - val_accuracy: 0.5664
# Epoch 118/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.5671 - val_loss: 0.6616 - val_accuracy: 0.5654
# Epoch 119/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6595 - accuracy: 0.5674 - val_loss: 0.6618 - val_accuracy: 0.5652
# Epoch 120/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6594 - accuracy: 0.5659 - val_loss: 0.6616 - val_accuracy: 0.5614
# Epoch 121/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.5668 - val_loss: 0.6618 - val_accuracy: 0.5674
# Epoch 122/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.5673 - val_loss: 0.6616 - val_accuracy: 0.5638
# Epoch 123/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.5667 - val_loss: 0.6620 - val_accuracy: 0.5680
# Epoch 124/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6593 - accuracy: 0.5672 - val_loss: 0.6620 - val_accuracy: 0.5655
# Epoch 125/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6594 - accuracy: 0.5677 - val_loss: 0.6619 - val_accuracy: 0.5616
# Epoch 126/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6594 - accuracy: 0.5667 - val_loss: 0.6619 - val_accuracy: 0.5697
# Epoch 127/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.5677 - val_loss: 0.6616 - val_accuracy: 0.5660
# Epoch 128/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.5671 - val_loss: 0.6617 - val_accuracy: 0.5645
# Epoch 129/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5667 - val_loss: 0.6615 - val_accuracy: 0.5653
# Epoch 130/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5676 - val_loss: 0.6616 - val_accuracy: 0.5673
# Epoch 131/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5672 - val_loss: 0.6617 - val_accuracy: 0.5658
# Epoch 132/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.5669 - val_loss: 0.6616 - val_accuracy: 0.5627
# Epoch 133/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6593 - accuracy: 0.5671 - val_loss: 0.6617 - val_accuracy: 0.5615
# Epoch 134/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6590 - accuracy: 0.5670 - val_loss: 0.6615 - val_accuracy: 0.5674
# Epoch 135/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6591 - accuracy: 0.5671 - val_loss: 0.6616 - val_accuracy: 0.5628
# Epoch 136/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5671 - val_loss: 0.6616 - val_accuracy: 0.5626
# Epoch 137/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6590 - accuracy: 0.5671 - val_loss: 0.6616 - val_accuracy: 0.5637
# Epoch 138/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6590 - accuracy: 0.5677 - val_loss: 0.6616 - val_accuracy: 0.5659
# Epoch 139/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5677 - val_loss: 0.6618 - val_accuracy: 0.5570
# Epoch 140/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.5671 - val_loss: 0.6617 - val_accuracy: 0.5646
# Epoch 141/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6590 - accuracy: 0.5665 - val_loss: 0.6614 - val_accuracy: 0.5685
# Epoch 142/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6591 - accuracy: 0.5674 - val_loss: 0.6616 - val_accuracy: 0.5620
# Epoch 143/150
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6588 - accuracy: 0.5674 - val_loss: 0.6615 - val_accuracy: 0.5695
# Epoch 144/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6590 - accuracy: 0.5679 - val_loss: 0.6616 - val_accuracy: 0.5631
# Epoch 145/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6589 - accuracy: 0.5673 - val_loss: 0.6613 - val_accuracy: 0.5634
# Epoch 146/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6590 - accuracy: 0.5672 - val_loss: 0.6617 - val_accuracy: 0.5675
# Epoch 147/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5670 - val_loss: 0.6617 - val_accuracy: 0.5659
# Epoch 148/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.5672 - val_loss: 0.6616 - val_accuracy: 0.5607
# Epoch 149/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5676 - val_loss: 0.6617 - val_accuracy: 0.5657
# Epoch 150/150
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6591 - accuracy: 0.5674 - val_loss: 0.6616 - val_accuracy: 0.5647

# %%
plt.plot( training_hist2.history['loss'] )
plt.plot( training_hist2.history['val_loss'] )

# %%
mymodel2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 18)]         0           []
#
#  tf.__operators__.getitem_1 (Sl  (None, 9)           0           ['input_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  (None, 9)           0           ['input_2[0][0]']
#  icingOpLambda)
#
#  sequential_1 (Sequential)      (None, 1)            3101        ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.stack (TFOpLambda)          (None, 2, 1)         0           ['sequential_1[0][0]',
#                                                                   'sequential_1[1][0]']
#
# ==================================================================================================
# Total params: 3,101
# Trainable params: 3,101
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
preds2 = mymodel2.predict( X_test, batch_size=1024 )
# Out:
# 116/116 [==============================] - 0s 651us/step

# %%
preds2
# Out:
# array([[[1.9776224e-01],
#         [3.2093981e-13]],
#
#        [[6.5016898e-04],
#         [2.4278926e-08]],
#
#        [[8.6194456e-02],
#         [5.3364112e-14]],
#
#        ...,
#
#        [[3.7935263e-01],
#         [1.8709206e-07]],
#
#        [[7.5024790e-01],
#         [5.1806720e-13]],
#
#        [[2.5104728e-01],
#         [1.4045918e-02]]], dtype=float32)

# %%
np.shape(preds2)
# Out:
# (118650, 2, 1)

# %%
fig,ax = plt.subplots(2,1,figsize=(9,14))

ax[0].hist( preds2[:,0][Y_test==0], density=True, bins=80)
ax[0].hist( preds2[:,0][Y_test==1], density=True, bins=80, alpha=0.7)


ax[1].hist( preds2[:,1][Y_test==0], density=True, bins=80)
ax[1].hist( preds2[:,1][Y_test==1], density=True, bins=80, alpha=0.7)

plt.show()

# %%
mymodel2.evaluate( X_test, Y_test )
# Out:
# 3708/3708 [==============================] - 5s 1ms/step - loss: 0.6616 - accuracy: 0.5647
# [0.6615695953369141, 0.5646944642066956]

# %%
fig,ax = plt.subplots(1,3,figsize=(24,8))

ax[0].hist2d( preds2[:,0][Y_test>-1], preds2[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())
ax[1].hist2d( preds2[:,0][Y_test==0], preds2[:,1][Y_test==0], bins=80, norm=mpl.colors.LogNorm())
ax[2].hist2d( preds2[:,0][Y_test==1], preds2[:,1][Y_test==1], bins=80, norm=mpl.colors.LogNorm())

plt.show()

# %% [markdown]
# # Stop here

# %%
asdfdsadfaf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1694832/1969555121.py in <module>
# ----> 1 asdfdsadfaf
#
# NameError: name 'asdfdsadfaf' is not defined

# %%
hp_mse_scale = 2.0

# %%
n = 9  # Number of features in input.

inputs = Input(shape=(2*n,))

classifier_nn = Sequential()
classifier_nn.add( Dense( 50, activation="relu", input_dim=n) )
classifier_nn.add( Dense( 50, activation="relu"))
classifier_nn.add( Dense( 1, activation="sigmoid"))

particle_inputs_model2 = classifier_nn( inputs[:,0:n] )
detector_inputs_model2 = classifier_nn( inputs[:,n:] )

output2 = tf.stack( [particle_inputs_model2, detector_inputs_model2], axis=1)


mymodel2b = Model( inputs=[inputs], outputs=[output2])

opt_adam = tf.keras.optimizers.Adam(learning_rate=learning_rate_setval, amsgrad=False )

mymodel2b.compile( loss=custom_loss, optimizer=opt_adam, metrics=['accuracy'] )

# %%
training_hist2b = mymodel2b.fit( X_train, Y_train, validation_data=(X_test, Y_test), 
            epochs=50, 
            batch_size=batch_size_setval,
           verbose=1)

# %%
plt.plot( training_hist2b.history['loss'] )
plt.plot( training_hist2b.history['val_loss'] )

# %%
preds2b = mymodel2b.predict( X_test, batch_size=1024 )

# %%
fig,ax = plt.subplots(1,3,figsize=(24,8))

ax[0].hist2d( preds2b[:,0][Y_test>-1], preds2b[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())
ax[1].hist2d( preds2b[:,0][Y_test==0], preds2b[:,1][Y_test==0], bins=80, norm=mpl.colors.LogNorm())
ax[2].hist2d( preds2b[:,0][Y_test==1], preds2b[:,1][Y_test==1], bins=80, norm=mpl.colors.LogNorm())

plt.show()

# %%
hp_mse_scale = 5.0

# %%
n = 9  # Number of features in input.

inputs = Input(shape=(2*n,))

classifier_nn = Sequential()
classifier_nn.add( Dense( 50, activation="relu", input_dim=n) )
classifier_nn.add( Dense( 50, activation="relu"))
classifier_nn.add( Dense( 1, activation="sigmoid"))

particle_inputs_model2 = classifier_nn( inputs[:,0:n] )
detector_inputs_model2 = classifier_nn( inputs[:,n:] )

output2 = tf.stack( [particle_inputs_model2, detector_inputs_model2], axis=1)


mymodel2c = Model( inputs=[inputs], outputs=[output2])

opt_adam = tf.keras.optimizers.Adam(learning_rate=learning_rate_setval, amsgrad=False )

mymodel2c.compile( loss=custom_loss, optimizer=opt_adam, metrics=['accuracy'] )

# %%
training_hist2c = mymodel2c.fit( X_train, Y_train, validation_data=(X_test, Y_test), 
            epochs=50, 
            batch_size=batch_size_setval,
           verbose=1)

# %%
plt.plot( training_hist2c.history['loss'] )
plt.plot( training_hist2c.history['val_loss'] )

# %%
preds2c = mymodel2c.predict( X_test, batch_size=1024 )

# %%
fig,ax = plt.subplots(1,3,figsize=(24,8))

ax[0].hist2d( preds2c[:,0][Y_test>-1], preds2c[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())
ax[1].hist2d( preds2c[:,0][Y_test==0], preds2c[:,1][Y_test==0], bins=80, norm=mpl.colors.LogNorm())
ax[2].hist2d( preds2c[:,0][Y_test==1], preds2c[:,1][Y_test==1], bins=80, norm=mpl.colors.LogNorm())

plt.show()

# %%
hp_mse_scale = 10.0

# %%
n = 9  # Number of features in input.

inputs = Input(shape=(2*n,))

classifier_nn = Sequential()
classifier_nn.add( Dense( 50, activation="relu", input_dim=n) )
classifier_nn.add( Dense( 50, activation="relu"))
classifier_nn.add( Dense( 1, activation="sigmoid"))

particle_inputs_model2 = classifier_nn( inputs[:,0:n] )
detector_inputs_model2 = classifier_nn( inputs[:,n:] )

output2 = tf.stack( [particle_inputs_model2, detector_inputs_model2], axis=1)


mymodel2d = Model( inputs=[inputs], outputs=[output2])

opt_adam = tf.keras.optimizers.Adam(learning_rate=learning_rate_setval, amsgrad=False )

mymodel2d.compile( loss=custom_loss, optimizer=opt_adam, metrics=['accuracy'] )

# %%
training_hist2d = mymodel2d.fit( X_train, Y_train, validation_data=(X_test, Y_test), 
            epochs=50, 
            batch_size=batch_size_setval,
           verbose=1)

# %%
plt.plot( training_hist2d.history['loss'] )
plt.plot( training_hist2d.history['val_loss'] )

# %%
preds2d = mymodel2d.predict( X_test, batch_size=1024 )

# %%
fig,ax = plt.subplots(1,3,figsize=(24,8))

ax[0].hist2d( preds2d[:,0][Y_test>-1], preds2d[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())
ax[1].hist2d( preds2d[:,0][Y_test==0], preds2d[:,1][Y_test==0], bins=80, norm=mpl.colors.LogNorm())
ax[2].hist2d( preds2d[:,0][Y_test==1], preds2d[:,1][Y_test==1], bins=80, norm=mpl.colors.LogNorm())

plt.show()

# %%
fig,ax = plt.subplots(4,3,figsize=(15,20))

nbins=60

ax[0][0].hist( preds2[:,0][Y_test==0], density=True, bins=nbins, label='Django')
ax[0][0].hist( preds2[:,0][Y_test==1], density=True, bins=nbins, label='Rapgap',alpha=0.7)

ax[1][0].hist( preds2b[:,0][Y_test==0], density=True, bins=nbins, label='Django')
ax[1][0].hist( preds2b[:,0][Y_test==1], density=True, bins=nbins, label='Rapgap', alpha=0.7)

ax[2][0].hist( preds2c[:,0][Y_test==0], density=True, bins=nbins)
ax[2][0].hist( preds2c[:,0][Y_test==1], density=True, bins=nbins, alpha=0.7)

ax[3][0].hist( preds2d[:,0][Y_test==0], density=True, bins=nbins)
ax[3][0].hist( preds2d[:,0][Y_test==1], density=True, bins=nbins, alpha=0.7)




ax[0][1].hist( preds2[:,1][Y_test==0], density=True, bins=nbins, label='Django')
ax[0][1].hist( preds2[:,1][Y_test==1], density=True, bins=nbins, label='Rapgap', alpha=0.7)

ax[1][1].hist( preds2b[:,1][Y_test==0], density=True, bins=nbins)
ax[1][1].hist( preds2b[:,1][Y_test==1], density=True, bins=nbins, alpha=0.7)

ax[2][1].hist( preds2c[:,1][Y_test==0], density=True, bins=nbins)
ax[2][1].hist( preds2c[:,1][Y_test==1], density=True, bins=nbins, alpha=0.7)

ax[3][1].hist( preds2d[:,1][Y_test==0], density=True, bins=nbins)
ax[3][1].hist( preds2d[:,1][Y_test==1], density=True, bins=nbins, alpha=0.7)


ax[0][2].hist2d( preds2[:,0][Y_test>-1], preds2[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())

ax[1][2].hist2d( preds2b[:,0][Y_test>-1], preds2b[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())

ax[2][2].hist2d( preds2c[:,0][Y_test>-1], preds2c[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())

ax[3][2].hist2d( preds2d[:,0][Y_test>-1], preds2d[:,1][Y_test>-1], bins=80, norm=mpl.colors.LogNorm())


ax[0][0].set_title('Particle inputs', fontsize=20)
ax[0][1].set_title('Detector inputs', fontsize=20)

ax[0][0].legend(loc='best', fontsize=15)
ax[0][1].legend(loc='best', fontsize=15)

ax[0][2].set_xlabel('Particle inputs', fontsize=12)

ax[0][2].set_ylabel('Detector inputs', fontsize=12)


ax[0][0].text(0.1*ax[0][0].get_xlim()[1], 0.9*ax[0][0].get_ylim()[1],'SF = 1.0',fontsize=20)
ax[1][0].text(0.1*ax[1][0].get_xlim()[1], 0.9*ax[1][0].get_ylim()[1],'SF = 2.0',fontsize=20)
ax[2][0].text(0.1*ax[2][0].get_xlim()[1], 0.9*ax[2][0].get_ylim()[1],'SF = 5.0',fontsize=20)
ax[3][0].text(0.1*ax[3][0].get_xlim()[1], 0.9*ax[3][0].get_ylim()[1],'SF = 10.0',fontsize=20)

plt.savefig('plots1.png',bbox_inches='tight')

plt.show()
